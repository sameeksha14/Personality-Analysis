# %%
from nltk.corpus import stopwords     # importing nltk.corpus library
import nltk                           # importing nltk package
nltk.download('stopwords')            # downloading stopwords from nltk
from nltk.stem.wordnet import WordNetLemmatizer  # importing WordNetLemmatizer form nltk.stem.wordnet library
import string                        # importing string library

from textblob.classifiers import NaiveBayesClassifier # importing textblob.classifiers
import pandas as pd                   # importing pandas
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\manis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
global df
global emotion
global text
global data
global stop_words
global punctuation
global lemmatized
global neg
global nb

# %%
df = pd.read_csv('data_emotion.csv', header=None)  # importing the dataset from data_emotion.csv file
emotion = pd.Series(df[0])

# %%
text = pd.Series(df[1])
text
# Out:
# 0       On days when I feel close to my partner and ot...
# 1       Every time I imagine that someone I love or I ...
# 2       When I had been obviously unjustly treated and...
# 3       When I think about the short time that we live...
# 4       At a gathering I found myself involuntarily si...
# 5       When I realized that I was directing the feeli...
# 6       I feel guilty when when I realize that I consi...
# 7       After my girlfriend had taken her exam we went...
# 8       When, for the first time I realized the meanin...
# 9       When a car is overtaking another and I am forc...
# 10      When I recently thought about the hard work it...
# 11        When I found a bristle in the liver paste tube.
# 12      When I was tired and unmotivated, I shouted at...
# 13      When I think that I do not study enough.  Afte...
# 14      When I pass an examination which I did not thi...
# 15      When one has arranged to meet someone and that...
# 16      When one is unjustly accused of something one ...
# 17      When one's studies seem hopelessly difficult a...
# 18      When one finds out that someone you know is no...
# 19      When one has been unjust, stupid towards someo...
# 20      When one has neglected or been unjust to a goo...
# 21              Passing an exam I did not expect to pass.
# 22      When I climbed up a tree to pick apples.  The ...
# 23      When excuses are necessary and I get out of do...
# 24                                When I had my children.
# 25      When my 2 year old son climbed up and sat on t...
# 26      When my partner was attacked and lost three te...
# 27      When I see children on T.V from areas devastat...
# 28      When I nearly walked on a blindworm and then s...
# 29      When I saw my 18 year old son grab an oxygen m...
#                               ...
# 7486    I forgot to zip up my trousers, this was not n...
# 7487                                             Peeping.
# 7488    I had a picnic with old classmates, we chatted...
# 7489    At night when I was alone at home (all the fam...
# 7490    When I saw that my bed at the hostel was a mes...
# 7491    During the Physics experiment session I did no...
# 7492    A man sexually aggressed a small girl in the b...
# 7493           Being unable to stop urinating on the bus.
# 7494    There were old people in a crowded bus and I d...
# 7495    It was the first time that I gave a birthday p...
# 7496    It was a week before the higher level results ...
# 7497    The surname of my brother was different from o...
# 7498    When I was in primary 6, my father died.  I wa...
# 7499    At hostel, my roommate was a very selfish pers...
# 7500    My friend had many female friends and I though...
# 7501    In the past I used to think that my mother was...
# 7502    In August,1983, the long awaited "big envelope...
# 7503    On Christmas eve,1984, I had just finished the...
# 7504    In September 1984, I was forced to live with s...
# 7505    This issue worried me rather than saddening me...
# 7506    My roommate liked to listen to some meaningles...
# 7507    Last Summer I went camping with some C.U stude...
# 7508                    I lied to one of my best friends.
# 7509           I received a letter from a distant friend.
# 7510    My parents were out and I was the eldest at ho...
# 7511    Two years back someone invited me to be the tu...
# 7512    I had taken the responsibility to do something...
# 7513    I was at home and I heard a loud sound of spit...
# 7514    I did not do the homework that the teacher had...
# 7515    I had shouted at my younger brother and he was...
# Name: 1, Length: 7516, dtype: object

# %%
type({'Text': text, 'Emotion': emotion})
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
neg = ['not', 'nor', 'neither', 'although', 'but', 'however', 'nonetheless', 'even though', 'except','despite', 'yet']

# %%
data = pd.DataFrame({'Text': text, 'Emotion': emotion})
data
# Out:
#                                                    Text  Emotion
# 0     On days when I feel close to my partner and ot...      joy
# 1     Every time I imagine that someone I love or I ...     fear
# 2     When I had been obviously unjustly treated and...    anger
# 3     When I think about the short time that we live...  sadness
# 4     At a gathering I found myself involuntarily si...  disgust
# 5     When I realized that I was directing the feeli...    shame
# 6     I feel guilty when when I realize that I consi...    guilt
# 7     After my girlfriend had taken her exam we went...      joy
# 8     When, for the first time I realized the meanin...     fear
# 9     When a car is overtaking another and I am forc...    anger
# 10    When I recently thought about the hard work it...  sadness
# 11      When I found a bristle in the liver paste tube.  disgust
# 12    When I was tired and unmotivated, I shouted at...    shame
# 13    When I think that I do not study enough.  Afte...    guilt
# 14    When I pass an examination which I did not thi...      joy
# 15    When one has arranged to meet someone and that...     fear
# 16    When one is unjustly accused of something one ...    anger
# 17    When one's studies seem hopelessly difficult a...  sadness
# 18    When one finds out that someone you know is no...  disgust
# 19    When one has been unjust, stupid towards someo...    shame
# 20    When one has neglected or been unjust to a goo...    guilt
# 21            Passing an exam I did not expect to pass.      joy
# 22    When I climbed up a tree to pick apples.  The ...     fear
# 23    When excuses are necessary and I get out of do...    guilt
# 24                              When I had my children.      joy
# 25    When my 2 year old son climbed up and sat on t...     fear
# 26    When my partner was attacked and lost three te...    anger
# 27    When I see children on T.V from areas devastat...  sadness
# 28    When I nearly walked on a blindworm and then s...  disgust
# 29    When I saw my 18 year old son grab an oxygen m...    shame
# ...                                                 ...      ...
# 7486  I forgot to zip up my trousers, this was not n...    shame
# 7487                                           Peeping.    guilt
# 7488  I had a picnic with old classmates, we chatted...      joy
# 7489  At night when I was alone at home (all the fam...     fear
# 7490  When I saw that my bed at the hostel was a mes...    anger
# 7491  During the Physics experiment session I did no...  sadness
# 7492  A man sexually aggressed a small girl in the b...  disgust
# 7493         Being unable to stop urinating on the bus.    shame
# 7494  There were old people in a crowded bus and I d...    guilt
# 7495  It was the first time that I gave a birthday p...      joy
# 7496  It was a week before the higher level results ...     fear
# 7497  The surname of my brother was different from o...    anger
# 7498  When I was in primary 6, my father died.  I wa...  sadness
# 7499  At hostel, my roommate was a very selfish pers...    guilt
# 7500  My friend had many female friends and I though...    shame
# 7501  In the past I used to think that my mother was...    guilt
# 7502  In August,1983, the long awaited "big envelope...      joy
# 7503  On Christmas eve,1984, I had just finished the...     fear
# 7504  In September 1984, I was forced to live with s...    anger
# 7505  This issue worried me rather than saddening me...     fear
# 7506  My roommate liked to listen to some meaningles...    anger
# 7507  Last Summer I went camping with some C.U stude...    shame
# 7508                  I lied to one of my best friends.    shame
# 7509         I received a letter from a distant friend.      joy
# 7510  My parents were out and I was the eldest at ho...     fear
# 7511  Two years back someone invited me to be the tu...    shame
# 7512  I had taken the responsibility to do something...    shame
# 7513  I was at home and I heard a loud sound of spit...     fear
# 7514  I did not do the homework that the teacher had...    guilt
# 7515  I had shouted at my younger brother and he was...     fear
#
# [7516 rows x 2 columns]

# %%
stop_words = set(stopwords.words('english')) 
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
punctuation= set(string.punctuation) 
punctuation
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
lemmatized = WordNetLemmatizer()
lemmatized

# %%
list_of_emotions=[]
list_of_emotions
# Out:
# []

# %%
df.head(n=7)
# Out:
#          0                                                  1    2
# 0      joy  On days when I feel close to my partner and ot...  NaN
# 1     fear  Every time I imagine that someone I love or I ...  NaN
# 2    anger  When I had been obviously unjustly treated and...  NaN
# 3  sadness  When I think about the short time that we live...  NaN
# 4  disgust  At a gathering I found myself involuntarily si...  NaN
# 5    shame  When I realized that I was directing the feeli...  NaN
# 6    guilt  I feel guilty when when I realize that I consi...  NaN

# %%
test_data_comments = data['Text']   
type(test_data_comments)
# Out:
# pandas.core.series.Series

# %%
test_data_emotions = data['Emotion']                 # Retrieving the 'Emotion' column from the dataset.
test_data_emotions = test_data_emotions[6000:]     # Selecting first 6000 emotions for training data.

# %%
def preprocess(doc):   
        # Removing stopwords and negative words. Also, converting all the words to lower case.
        stop_excluding = " ".join([i for i in doc.lower().split() if i not in stop_words if i not in neg])
        
        # Removing all punctuations from the above preprocessed data.
        punc_free = "".join([ch for ch in stop_excluding if ch not in punctuation])
        
        # Lemmatizing all the words(the data is free of stopwords,negative words and punctuation)
        normalized = " ".join([lemmatized.lemmatize(word) for word in punc_free.split()])
        return normalized
for i in range(df.shape[0]):
    data.loc[i]['Text'] = preprocess(data.loc[i]['Text'])

# %%
myTuple = ("John", "Peter", "Vicky")

x = "#".join(myTuple)

print(x)
# Out:
# John#Peter#Vicky

# %%
thisdict =	{
  "brand": "Ford,bob",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford,bob', 'model': 'Mustang', 'year': 1964}

# %%
x = thisdict["brand"]
x
# Out:
# 'Ford,bob'
