# %% [markdown]
# # <black>Importing all the necessary libraries required.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
trainDataframe = pd.read_csv('train.csv', names=["type", "tweets"], dtype={
    "type": str, "tweets": str})
testDataframe = pd.read_csv('test.csv', names=["type", "tweets"], dtype={
    "type": str, "tweets": str})
testSingleDataframe = pd.read_csv('testSingle.csv', names=["type", "tweets"], dtype={
    "type": str, "tweets": str})
TWEETS_PER_PERSON = 50

personalities = {
    "extrovert": {"I": 0, "E": 1},    # key-pair values
    "sensible": {"N": 0, "S": 1},
    "emotional": {"T": 0, "F": 1},
    "perceiving": {"J": 0, "P": 1}
}
attribute_counters = {
    "Longs_PT": "...",
    "Surprise_PT": "!",
    "Images_PT": "jpg",
    "Questions_PT": "?",
    "Music_PT": "music",
    "URLS_PT": "http",
    "Words_PT": " "
}
def processXY(df, isCheck=False):
    index = 0
    if not isCheck:
        for personality, symbol_map in personalities.items():
            # generate numeric column for each personality type
            # since model can only be trained on numeric column
            df[personality] = df["type"].str[index].map(symbol_map)
            index += 1

    for newcol, newcolcounter in attribute_counters.items():
        df[newcol] = df["tweets"].apply(
            lambda x: x.count(newcolcounter) / TWEETS_PER_PERSON)

    df = df.fillna(0)
    # example
    print(df.Surprise_PT)
       
    X = None

    # drop non-numeric columns
    
    if isCheck:
        X = df.drop(["type", "tweets"], axis=1).values     # axis=1 means column drop; axis=0 means row drop
    else:
        X = df.drop(["type", "emotional", "sensible",
                     "extrovert", "perceiving", "tweets"], axis=1).values

    # Change this string to check different person type
    Y = [] if isCheck else df[["extrovert"]].values.ravel()

    return (X, Y)

# %%
X_train, y_train = processXY(trainDataframe)
X_test, y_test = processXY(testDataframe)
# Out:
# 0       0.06
# 1       0.00
# 2       0.08
# 3       0.06
# 4       0.02
# 5       0.00
# 6       0.06
# 7       0.00
# 8       0.02
# 9       0.06
# 10      0.20
# 11      0.56
# 12      0.16
# 13      0.12
# 14      0.04
# 15      0.08
# 16      0.40
# 17      0.20
# 18      0.12
# 19      0.10
# 20      0.04
# 21      0.02
# 22      0.40
# 23      0.08
# 24      0.10
# 25      0.22
# 26      0.24
# 27      0.24
# 28      0.12
# 29      0.14
#         ...
# 6970    0.12
# 6971    0.00
# 6972    0.08
# 6973    0.52
# 6974    0.02
# 6975    0.34
# 6976    0.24
# 6977    0.02
# 6978    0.02
# 6979    0.08
# 6980    0.10
# 6981    0.08
# 6982    1.28
# 6983    0.42
# 6984    0.22
# 6985    0.18
# 6986    0.10
# 6987    0.06
# 6988    0.02
# 6989    0.02
# 6990    0.00
# 6991    0.14
# 6992    0.00
# 6993    0.12
# 6994    0.00
# 6995    0.02
# 6996    0.06
# 6997    0.86
# 6998    0.42
# 6999    0.40
# Name: Surprise_PT, Length: 7000, dtype: float64
# 0      0.42
# 1      0.26
# 2      0.10
# 3      0.20
# 4      0.20
# 5      0.70
# 6      0.28
# 7      0.08
# 8      0.10
# 9      0.10
# 10     0.10
# 11     0.12
# 12     0.02
# 13     0.14
# 14     0.14
# 15     0.12
# 16     0.52
# 17     0.02
# 18     0.16
# 19     0.04
# 20     0.20
# 21     0.06
# 22     0.04
# 23     0.06
# 24     0.00
# 25     0.06
# 26     0.02
# 27     0.36
# 28     0.38
# 29     0.26
#        ...
# 970    0.42
# 971    0.02
# 972    0.36
# 973    0.24
# 974    0.08
# 975    0.10
# 976    0.02
# 977    0.02
# 978    0.18
# 979    0.06
# 980    0.02
# 981    0.00
# 982    0.16
# 983    0.22
# 984    0.48
# 985    0.06
# 986    0.38
# 987    0.06
# 988    0.06
# 989    0.22
# 990    0.22
# 991    0.50
# 992    0.24
# 993    0.96
# 994    0.12
# 995    0.22
# 996    0.02
# 997    0.00
# 998    0.00
# 999    1.26
# Name: Surprise_PT, Length: 1000, dtype: float64

# %% [markdown]
# ## Applying Logistic Regression

# %%
model = LogisticRegression(solver="newton-cg", max_iter=100)
model.fit(X_train, y_train)

accuracy = round(model.score(X_test, y_test) * 100, 2)
print(round(accuracy, 2, ), "% (Accuracy)")            # 75.6% accuracy
# Out:
# 75.6 % (Accuracy)

# %% [markdown]
# ## Testing the Trained Model

# %%
# to display predictions for test single 
X_singletest, y_temp = processXY(testSingleDataframe, isCheck=True)
y_answer = model.predict(X_singletest)
s = "Extrovert" if y_answer[0] else "Introvert"
print(f"The single test case is {s}")

exit(0)
print("Other tests are as follows:")
# display predictions for all people
for i in range(X_test.shape[0]):
    s = "Extrovert" if y_test[i] else "Introvert"
    print(f"Person {i + 1} = {s}")
# Out:
# 0    0.22
# Name: Surprise_PT, dtype: float64
# The single test case is Introvert
# Other tests are as follows:
# Person 1 = Extrovert
# Person 2 = Introvert
# Person 3 = Extrovert
# Person 4 = Introvert
# Person 5 = Introvert
# Person 6 = Extrovert
# Person 7 = Extrovert
# Person 8 = Introvert
# Person 9 = Introvert
# Person 10 = Introvert
# Person 11 = Introvert
# Person 12 = Introvert
# Person 13 = Introvert
# Person 14 = Extrovert
# Person 15 = Introvert
# Person 16 = Introvert
# Person 17 = Introvert
# Person 18 = Extrovert
# Person 19 = Extrovert
# Person 20 = Introvert
# Person 21 = Introvert
# Person 22 = Introvert
# Person 23 = Introvert
# Person 24 = Introvert
# Person 25 = Introvert
# Person 26 = Introvert
# Person 27 = Introvert
# Person 28 = Extrovert
# Person 29 = Introvert
# Person 30 = Introvert
# Person 31 = Introvert
# Person 32 = Introvert
# Person 33 = Introvert
# Person 34 = Extrovert
# Person 35 = Extrovert
# Person 36 = Introvert
# Person 37 = Introvert
# Person 38 = Extrovert
# Person 39 = Introvert
# Person 40 = Introvert
# Person 41 = Introvert
# Person 42 = Extrovert
# Person 43 = Introvert
# Person 44 = Introvert
# Person 45 = Extrovert
# Person 46 = Introvert
# Person 47 = Extrovert
# Person 48 = Introvert
# Person 49 = Extrovert
# Person 50 = Introvert
# Person 51 = Extrovert
# Person 52 = Introvert
# Person 53 = Introvert
# Person 54 = Introvert
# Person 55 = Extrovert
# Person 56 = Extrovert
# Person 57 = Extrovert
# Person 58 = Introvert
# Person 59 = Introvert
# Person 60 = Introvert
# Person 61 = Introvert
# Person 62 = Introvert
# Person 63 = Extrovert
# Person 64 = Introvert
# Person 65 = Extrovert
# Person 66 = Introvert
# Person 67 = Extrovert
# Person 68 = Extrovert
# Person 69 = Introvert
# Person 70 = Introvert
# Person 71 = Introvert
# Person 72 = Introvert
# Person 73 = Introvert
# Person 74 = Extrovert
# Person 75 = Introvert
# Person 76 = Extrovert
# Person 77 = Introvert
# Person 78 = Extrovert
# Person 79 = Introvert
# Person 80 = Introvert
# Person 81 = Introvert
# Person 82 = Introvert
# Person 83 = Introvert
# Person 84 = Introvert
# Person 85 = Introvert
# Person 86 = Introvert
# Person 87 = Introvert
# Person 88 = Introvert
# Person 89 = Introvert
# Person 90 = Introvert
# Person 91 = Introvert
# Person 92 = Introvert
# Person 93 = Introvert
# Person 94 = Introvert
# Person 95 = Introvert
# Person 96 = Introvert
# Person 97 = Introvert
# Person 98 = Extrovert
# Person 99 = Introvert
# Person 100 = Introvert
# Person 101 = Introvert
# Person 102 = Extrovert
# Person 103 = Introvert
# Person 104 = Introvert
# Person 105 = Introvert
# Person 106 = Introvert
# Person 107 = Introvert
# Person 108 = Extrovert
# Person 109 = Introvert
# Person 110 = Introvert
# Person 111 = Extrovert
# Person 112 = Introvert
# Person 113 = Introvert
# Person 114 = Introvert
# Person 115 = Introvert
# Person 116 = Introvert
# Person 117 = Introvert
# Person 118 = Extrovert
# Person 119 = Extrovert
# Person 120 = Extrovert
# Person 121 = Extrovert
# Person 122 = Extrovert
# Person 123 = Introvert
# Person 124 = Introvert
# Person 125 = Extrovert
# Person 126 = Introvert
# Person 127 = Introvert
# Person 128 = Introvert
# Person 129 = Extrovert
# Person 130 = Extrovert
# Person 131 = Introvert
# Person 132 = Introvert
# Person 133 = Introvert
# Person 134 = Introvert
# Person 135 = Introvert
# Person 136 = Introvert
# Person 137 = Introvert
# Person 138 = Introvert
# Person 139 = Introvert
# Person 140 = Introvert
# Person 141 = Extrovert
# Person 142 = Extrovert
# Person 143 = Extrovert
# Person 144 = Extrovert
# Person 145 = Introvert
# Person 146 = Extrovert
# Person 147 = Introvert
# Person 148 = Extrovert
# Person 149 = Introvert
# Person 150 = Introvert
# Person 151 = Introvert
# Person 152 = Introvert
# Person 153 = Introvert
# Person 154 = Introvert
# Person 155 = Introvert
# Person 156 = Introvert
# Person 157 = Extrovert
# Person 158 = Introvert
# Person 159 = Introvert
# Person 160 = Introvert
# Person 161 = Introvert
# Person 162 = Introvert
# Person 163 = Introvert
# Person 164 = Extrovert
# Person 165 = Introvert
# Person 166 = Extrovert
# Person 167 = Extrovert
# Person 168 = Introvert
# Person 169 = Introvert
# Person 170 = Extrovert
# Person 171 = Introvert
# Person 172 = Introvert
# Person 173 = Extrovert
# Person 174 = Introvert
# Person 175 = Introvert
# Person 176 = Introvert
# Person 177 = Introvert
# Person 178 = Extrovert
# Person 179 = Extrovert
# Person 180 = Introvert
# Person 181 = Extrovert
# Person 182 = Introvert
# Person 183 = Extrovert
# Person 184 = Introvert
# Person 185 = Introvert
# Person 186 = Introvert
# Person 187 = Extrovert
# Person 188 = Introvert
# Person 189 = Extrovert
# Person 190 = Introvert
# Person 191 = Introvert
# Person 192 = Introvert
# Person 193 = Introvert
# Person 194 = Extrovert
# Person 195 = Introvert
# Person 196 = Extrovert
# Person 197 = Introvert
# Person 198 = Extrovert
# Person 199 = Extrovert
# Person 200 = Introvert
# Person 201 = Introvert
# Person 202 = Introvert
# Person 203 = Extrovert
# Person 204 = Introvert
# Person 205 = Introvert
# Person 206 = Extrovert
# Person 207 = Extrovert
# Person 208 = Extrovert
# Person 209 = Introvert
# Person 210 = Extrovert
# Person 211 = Extrovert
# Person 212 = Extrovert
# Person 213 = Introvert
# Person 214 = Extrovert
# Person 215 = Introvert
# Person 216 = Extrovert
# Person 217 = Introvert
# Person 218 = Introvert
# Person 219 = Introvert
# Person 220 = Introvert
# Person 221 = Introvert
# Person 222 = Introvert
# Person 223 = Introvert
# Person 224 = Introvert
# Person 225 = Introvert
# Person 226 = Introvert
# Person 227 = Introvert
# Person 228 = Extrovert
# Person 229 = Introvert
# Person 230 = Introvert
# Person 231 = Introvert
# Person 232 = Introvert
# Person 233 = Introvert
# Person 234 = Introvert
# Person 235 = Introvert
# Person 236 = Introvert
# Person 237 = Introvert
# Person 238 = Introvert
# Person 239 = Extrovert
# Person 240 = Introvert
# Person 241 = Introvert
# Person 242 = Extrovert
# Person 243 = Introvert
# Person 244 = Introvert
# Person 245 = Introvert
# Person 246 = Extrovert
# Person 247 = Introvert
# Person 248 = Extrovert
# Person 249 = Introvert
# Person 250 = Introvert
# Person 251 = Introvert
# Person 252 = Introvert
# Person 253 = Introvert
# Person 254 = Introvert
# Person 255 = Introvert
# Person 256 = Extrovert
# Person 257 = Introvert
# Person 258 = Introvert
# Person 259 = Introvert
# Person 260 = Extrovert
# Person 261 = Introvert
# Person 262 = Introvert
# Person 263 = Introvert
# Person 264 = Introvert
# Person 265 = Introvert
# Person 266 = Extrovert
# Person 267 = Introvert
# Person 268 = Introvert
# Person 269 = Extrovert
# Person 270 = Introvert
# Person 271 = Introvert
# Person 272 = Introvert
# Person 273 = Introvert
# Person 274 = Extrovert
# Person 275 = Introvert
# Person 276 = Introvert
# Person 277 = Extrovert
# Person 278 = Introvert
# Person 279 = Extrovert
# Person 280 = Extrovert
# Person 281 = Introvert
# Person 282 = Extrovert
# Person 283 = Introvert
# Person 284 = Extrovert
# Person 285 = Introvert
# Person 286 = Introvert
# Person 287 = Extrovert
# Person 288 = Introvert
# Person 289 = Extrovert
# Person 290 = Extrovert
# Person 291 = Introvert
# Person 292 = Extrovert
# Person 293 = Introvert
# Person 294 = Introvert
# Person 295 = Introvert
# Person 296 = Introvert
# Person 297 = Introvert
# Person 298 = Extrovert
# Person 299 = Introvert
# Person 300 = Introvert
# Person 301 = Introvert
# Person 302 = Introvert
# Person 303 = Introvert
# Person 304 = Extrovert
# Person 305 = Introvert
# Person 306 = Extrovert
# Person 307 = Introvert
# Person 308 = Introvert
# Person 309 = Introvert
# Person 310 = Extrovert
# Person 311 = Introvert
# Person 312 = Extrovert
# Person 313 = Introvert
# Person 314 = Extrovert
# Person 315 = Introvert
# Person 316 = Introvert
# Person 317 = Introvert
# Person 318 = Introvert
# Person 319 = Introvert
# Person 320 = Introvert
# Person 321 = Introvert
# Person 322 = Introvert
# Person 323 = Extrovert
# Person 324 = Introvert
# Person 325 = Introvert
# Person 326 = Introvert
# Person 327 = Introvert
# Person 328 = Introvert
# Person 329 = Extrovert
# Person 330 = Introvert
# Person 331 = Introvert
# Person 332 = Introvert
# Person 333 = Introvert
# Person 334 = Extrovert
# Person 335 = Extrovert
# Person 336 = Introvert
# Person 337 = Introvert
# Person 338 = Introvert
# Person 339 = Introvert
# Person 340 = Introvert
# Person 341 = Introvert
# Person 342 = Introvert
# Person 343 = Introvert
# Person 344 = Extrovert
# Person 345 = Introvert
# Person 346 = Introvert
# Person 347 = Introvert
# Person 348 = Extrovert
# Person 349 = Introvert
# Person 350 = Introvert
# Person 351 = Introvert
# Person 352 = Extrovert
# Person 353 = Introvert
# Person 354 = Introvert
# Person 355 = Introvert
# Person 356 = Introvert
# Person 357 = Introvert
# Person 358 = Extrovert
# Person 359 = Extrovert
# Person 360 = Introvert
# Person 361 = Introvert
# Person 362 = Introvert
# Person 363 = Introvert
# Person 364 = Introvert
# Person 365 = Introvert
# Person 366 = Introvert
# Person 367 = Introvert
# Person 368 = Extrovert
# Person 369 = Introvert
# Person 370 = Introvert
# Person 371 = Introvert
# Person 372 = Introvert
# Person 373 = Introvert
# Person 374 = Introvert
# Person 375 = Introvert
# Person 376 = Introvert
# Person 377 = Extrovert
# Person 378 = Extrovert
# Person 379 = Extrovert
# Person 380 = Introvert
# Person 381 = Extrovert
# Person 382 = Introvert
# Person 383 = Introvert
# Person 384 = Introvert
# Person 385 = Introvert
# Person 386 = Extrovert
# Person 387 = Introvert
# Person 388 = Extrovert
# Person 389 = Introvert
# Person 390 = Introvert
# Person 391 = Introvert
# Person 392 = Introvert
# Person 393 = Introvert
# Person 394 = Introvert
# Person 395 = Introvert
# Person 396 = Introvert
# Person 397 = Introvert
# Person 398 = Extrovert
# Person 399 = Introvert
# Person 400 = Extrovert
# Person 401 = Extrovert
# Person 402 = Extrovert
# Person 403 = Extrovert
# Person 404 = Extrovert
# Person 405 = Introvert
# Person 406 = Introvert
# Person 407 = Introvert
# Person 408 = Extrovert
# Person 409 = Extrovert
# Person 410 = Introvert
# Person 411 = Introvert
# Person 412 = Introvert
# Person 413 = Introvert
# Person 414 = Introvert
# Person 415 = Introvert
# Person 416 = Extrovert
# Person 417 = Introvert
# Person 418 = Introvert
# Person 419 = Extrovert
# Person 420 = Introvert
# Person 421 = Introvert
# Person 422 = Introvert
# Person 423 = Introvert
# Person 424 = Extrovert
# Person 425 = Introvert
# Person 426 = Introvert
# Person 427 = Introvert
# Person 428 = Introvert
# Person 429 = Introvert
# Person 430 = Introvert
# Person 431 = Introvert
# Person 432 = Introvert
# Person 433 = Introvert
# Person 434 = Extrovert
# Person 435 = Introvert
# Person 436 = Introvert
# Person 437 = Extrovert
# Person 438 = Introvert
# Person 439 = Introvert
# Person 440 = Introvert
# Person 441 = Introvert
# Person 442 = Introvert
# Person 443 = Introvert
# Person 444 = Introvert
# Person 445 = Introvert
# Person 446 = Extrovert
# Person 447 = Introvert
# Person 448 = Introvert
# Person 449 = Introvert
# Person 450 = Introvert
# Person 451 = Introvert
# Person 452 = Introvert
# Person 453 = Extrovert
# Person 454 = Introvert
# Person 455 = Introvert
# Person 456 = Introvert
# Person 457 = Introvert
# Person 458 = Introvert
# Person 459 = Introvert
# Person 460 = Extrovert
# Person 461 = Introvert
# Person 462 = Introvert
# Person 463 = Introvert
# Person 464 = Introvert
# Person 465 = Extrovert
# Person 466 = Introvert
# Person 467 = Introvert
# Person 468 = Extrovert
# Person 469 = Introvert
# Person 470 = Introvert
# Person 471 = Extrovert
# Person 472 = Introvert
# Person 473 = Introvert
# Person 474 = Extrovert
# Person 475 = Introvert
# Person 476 = Introvert
# Person 477 = Introvert
# Person 478 = Introvert
# Person 479 = Introvert
# Person 480 = Introvert
# Person 481 = Introvert
# Person 482 = Introvert
# Person 483 = Introvert
# Person 484 = Introvert
# Person 485 = Introvert
# Person 486 = Introvert
# Person 487 = Introvert
# Person 488 = Introvert
# Person 489 = Extrovert
# Person 490 = Introvert
# Person 491 = Introvert
# Person 492 = Introvert
# Person 493 = Introvert
# Person 494 = Introvert
# Person 495 = Extrovert
# Person 496 = Introvert
# Person 497 = Introvert
# Person 498 = Introvert
# Person 499 = Introvert
# Person 500 = Introvert
# Person 501 = Introvert
# Person 502 = Introvert
# Person 503 = Introvert
# Person 504 = Introvert
# Person 505 = Introvert
# Person 506 = Introvert
# Person 507 = Introvert
# Person 508 = Extrovert
# Person 509 = Introvert
# Person 510 = Extrovert
# Person 511 = Introvert
# Person 512 = Introvert
# Person 513 = Extrovert
# Person 514 = Introvert
# Person 515 = Introvert
# Person 516 = Extrovert
# Person 517 = Introvert
# Person 518 = Introvert
# Person 519 = Introvert
# Person 520 = Extrovert
# Person 521 = Introvert
# Person 522 = Extrovert
# Person 523 = Introvert
# Person 524 = Introvert
# Person 525 = Extrovert
# Person 526 = Introvert
# Person 527 = Introvert
# Person 528 = Introvert
# Person 529 = Introvert
# Person 530 = Introvert
# Person 531 = Introvert
# Person 532 = Extrovert
# Person 533 = Introvert
# Person 534 = Extrovert
# Person 535 = Introvert
# Person 536 = Introvert
# Person 537 = Introvert
# Person 538 = Introvert
# Person 539 = Extrovert
# Person 540 = Extrovert
# Person 541 = Introvert
# Person 542 = Introvert
# Person 543 = Introvert
# Person 544 = Introvert
# Person 545 = Introvert
# Person 546 = Extrovert
# Person 547 = Introvert
# Person 548 = Introvert
# Person 549 = Introvert
# Person 550 = Introvert
# Person 551 = Introvert
# Person 552 = Introvert
# Person 553 = Introvert
# Person 554 = Introvert
# Person 555 = Introvert
# Person 556 = Extrovert
# Person 557 = Introvert
# Person 558 = Introvert
# Person 559 = Introvert
# Person 560 = Introvert
# Person 561 = Introvert
# Person 562 = Introvert
# Person 563 = Introvert
# Person 564 = Introvert
# Person 565 = Introvert
# Person 566 = Introvert
# Person 567 = Extrovert
# Person 568 = Extrovert
# Person 569 = Extrovert
# Person 570 = Introvert
# Person 571 = Extrovert
# Person 572 = Introvert
# Person 573 = Introvert
# Person 574 = Introvert
# Person 575 = Introvert
# Person 576 = Extrovert
# Person 577 = Introvert
# Person 578 = Introvert
# Person 579 = Extrovert
# Person 580 = Introvert
# Person 581 = Extrovert
# Person 582 = Extrovert
# Person 583 = Extrovert
# Person 584 = Extrovert
# Person 585 = Introvert
# Person 586 = Introvert
# Person 587 = Introvert
# Person 588 = Introvert
# Person 589 = Extrovert
# Person 590 = Introvert
# Person 591 = Introvert
# Person 592 = Introvert
# Person 593 = Extrovert
# Person 594 = Introvert
# Person 595 = Extrovert
# Person 596 = Introvert
# Person 597 = Introvert
# Person 598 = Introvert
# Person 599 = Extrovert
# Person 600 = Introvert
# Person 601 = Extrovert
# Person 602 = Extrovert
# Person 603 = Introvert
# Person 604 = Introvert
# Person 605 = Extrovert
# Person 606 = Introvert
# Person 607 = Introvert
# Person 608 = Introvert
# Person 609 = Introvert
# Person 610 = Introvert
# Person 611 = Introvert
# Person 612 = Introvert
# Person 613 = Extrovert
# Person 614 = Extrovert
# Person 615 = Introvert
# Person 616 = Introvert
# Person 617 = Introvert
# Person 618 = Introvert
# Person 619 = Introvert
# Person 620 = Introvert
# Person 621 = Introvert
# Person 622 = Introvert
# Person 623 = Introvert
# Person 624 = Extrovert
# Person 625 = Introvert
# Person 626 = Introvert
# Person 627 = Introvert
# Person 628 = Extrovert
# Person 629 = Introvert
# Person 630 = Extrovert
# Person 631 = Extrovert
# Person 632 = Introvert
# Person 633 = Introvert
# Person 634 = Introvert
# Person 635 = Introvert
# Person 636 = Extrovert
# Person 637 = Introvert
# Person 638 = Introvert
# Person 639 = Introvert
# Person 640 = Extrovert
# Person 641 = Extrovert
# Person 642 = Introvert
# Person 643 = Introvert
# Person 644 = Introvert
# Person 645 = Introvert
# Person 646 = Introvert
# Person 647 = Extrovert
# Person 648 = Introvert
# Person 649 = Introvert
# Person 650 = Introvert
# Person 651 = Introvert
# Person 652 = Introvert
# Person 653 = Introvert
# Person 654 = Extrovert
# Person 655 = Introvert
# Person 656 = Introvert
# Person 657 = Introvert
# Person 658 = Extrovert
# Person 659 = Introvert
# Person 660 = Introvert
# Person 661 = Introvert
# Person 662 = Extrovert
# Person 663 = Extrovert
# Person 664 = Introvert
# Person 665 = Introvert
# Person 666 = Introvert
# Person 667 = Introvert
# Person 668 = Introvert
# Person 669 = Introvert
# Person 670 = Introvert
# Person 671 = Introvert
# Person 672 = Introvert
# Person 673 = Extrovert
# Person 674 = Introvert
# Person 675 = Introvert
# Person 676 = Introvert
# Person 677 = Introvert
# Person 678 = Introvert
# Person 679 = Introvert
# Person 680 = Introvert
# Person 681 = Introvert
# Person 682 = Introvert
# Person 683 = Introvert
# Person 684 = Introvert
# Person 685 = Introvert
# Person 686 = Introvert
# Person 687 = Introvert
# Person 688 = Extrovert
# Person 689 = Introvert
# Person 690 = Introvert
# Person 691 = Introvert
# Person 692 = Introvert
# Person 693 = Introvert
# Person 694 = Introvert
# Person 695 = Introvert
# Person 696 = Extrovert
# Person 697 = Introvert
# Person 698 = Introvert
# Person 699 = Extrovert
# Person 700 = Introvert
# Person 701 = Introvert
# Person 702 = Introvert
# Person 703 = Introvert
# Person 704 = Introvert
# Person 705 = Introvert
# Person 706 = Introvert
# Person 707 = Introvert
# Person 708 = Introvert
# Person 709 = Introvert
# Person 710 = Extrovert
# Person 711 = Extrovert
# Person 712 = Introvert
# Person 713 = Introvert
# Person 714 = Introvert
# Person 715 = Extrovert
# Person 716 = Introvert
# Person 717 = Extrovert
# Person 718 = Introvert
# Person 719 = Introvert
# Person 720 = Introvert
# Person 721 = Introvert
# Person 722 = Introvert
# Person 723 = Introvert
# Person 724 = Introvert
# Person 725 = Introvert
# Person 726 = Extrovert
# Person 727 = Extrovert
# Person 728 = Extrovert
# Person 729 = Extrovert
# Person 730 = Introvert
# Person 731 = Introvert
# Person 732 = Introvert
# Person 733 = Extrovert
# Person 734 = Introvert
# Person 735 = Extrovert
# Person 736 = Introvert
# Person 737 = Introvert
# Person 738 = Introvert
# Person 739 = Introvert
# Person 740 = Introvert
# Person 741 = Introvert
# Person 742 = Introvert
# Person 743 = Extrovert
# Person 744 = Introvert
# Person 745 = Introvert
# Person 746 = Introvert
# Person 747 = Introvert
# Person 748 = Introvert
# Person 749 = Extrovert
# Person 750 = Introvert
# Person 751 = Introvert
# Person 752 = Introvert
# Person 753 = Introvert
# Person 754 = Introvert
# Person 755 = Introvert
# Person 756 = Extrovert
# Person 757 = Introvert
# Person 758 = Introvert
# Person 759 = Extrovert
# Person 760 = Introvert
# Person 761 = Introvert
# Person 762 = Introvert
# Person 763 = Introvert
# Person 764 = Extrovert
# Person 765 = Introvert
# Person 766 = Introvert
# Person 767 = Introvert
# Person 768 = Introvert
# Person 769 = Introvert
# Person 770 = Introvert
# Person 771 = Extrovert
# Person 772 = Introvert
# Person 773 = Introvert
# Person 774 = Introvert
# Person 775 = Introvert
# Person 776 = Introvert
# Person 777 = Extrovert
# Person 778 = Extrovert
# Person 779 = Extrovert
# Person 780 = Introvert
# Person 781 = Introvert
# Person 782 = Introvert
# Person 783 = Extrovert
# Person 784 = Introvert
# Person 785 = Introvert
# Person 786 = Introvert
# Person 787 = Introvert
# Person 788 = Introvert
# Person 789 = Extrovert
# Person 790 = Introvert
# Person 791 = Extrovert
# Person 792 = Introvert
# Person 793 = Extrovert
# Person 794 = Extrovert
# Person 795 = Introvert
# Person 796 = Introvert
# Person 797 = Introvert
# Person 798 = Extrovert
# Person 799 = Introvert
# Person 800 = Introvert
# Person 801 = Introvert
# Person 802 = Introvert
# Person 803 = Introvert
# Person 804 = Introvert
# Person 805 = Extrovert
# Person 806 = Extrovert
# Person 807 = Introvert
# Person 808 = Introvert
# Person 809 = Introvert
# Person 810 = Introvert
# Person 811 = Introvert
# Person 812 = Extrovert
# Person 813 = Introvert
# Person 814 = Introvert
# Person 815 = Introvert
# Person 816 = Introvert
# Person 817 = Introvert
# Person 818 = Introvert
# Person 819 = Extrovert
# Person 820 = Extrovert
# Person 821 = Introvert
# Person 822 = Introvert
# Person 823 = Introvert
# Person 824 = Introvert
# Person 825 = Introvert
# Person 826 = Introvert
# Person 827 = Introvert
# Person 828 = Extrovert
# Person 829 = Introvert
# Person 830 = Extrovert
# Person 831 = Introvert
# Person 832 = Extrovert
# Person 833 = Introvert
# Person 834 = Introvert
# Person 835 = Introvert
# Person 836 = Extrovert
# Person 837 = Extrovert
# Person 838 = Extrovert
# Person 839 = Introvert
# Person 840 = Introvert
# Person 841 = Introvert
# Person 842 = Introvert
# Person 843 = Introvert
# Person 844 = Introvert
# Person 845 = Introvert
# Person 846 = Extrovert
# Person 847 = Extrovert
# Person 848 = Introvert
# Person 849 = Introvert
# Person 850 = Extrovert
# Person 851 = Introvert
# Person 852 = Introvert
# Person 853 = Introvert
# Person 854 = Introvert
# Person 855 = Introvert
# Person 856 = Extrovert
# Person 857 = Introvert
# Person 858 = Introvert
# Person 859 = Introvert
# Person 860 = Extrovert
# Person 861 = Introvert
# Person 862 = Extrovert
# Person 863 = Introvert
# Person 864 = Extrovert
# Person 865 = Introvert
# Person 866 = Extrovert
# Person 867 = Introvert
# Person 868 = Introvert
# Person 869 = Introvert
# Person 870 = Introvert
# Person 871 = Introvert
# Person 872 = Introvert
# Person 873 = Introvert
# Person 874 = Introvert
# Person 875 = Introvert
# Person 876 = Introvert
# Person 877 = Introvert
# Person 878 = Introvert
# Person 879 = Extrovert
# Person 880 = Introvert
# Person 881 = Introvert
# Person 882 = Introvert
# Person 883 = Introvert
# Person 884 = Introvert
# Person 885 = Introvert
# Person 886 = Introvert
# Person 887 = Introvert
# Person 888 = Introvert
# Person 889 = Introvert
# Person 890 = Extrovert
# Person 891 = Introvert
# Person 892 = Introvert
# Person 893 = Introvert
# Person 894 = Introvert
# Person 895 = Introvert
# Person 896 = Introvert
# Person 897 = Introvert
# Person 898 = Extrovert
# Person 899 = Introvert
# Person 900 = Introvert
# Person 901 = Introvert
# Person 902 = Introvert
# Person 903 = Introvert
# Person 904 = Introvert
# Person 905 = Introvert
# Person 906 = Extrovert
# Person 907 = Extrovert
# Person 908 = Extrovert
# Person 909 = Extrovert
# Person 910 = Introvert
# Person 911 = Extrovert
# Person 912 = Introvert
# Person 913 = Introvert
# Person 914 = Introvert
# Person 915 = Introvert
# Person 916 = Introvert
# Person 917 = Introvert
# Person 918 = Introvert
# Person 919 = Introvert
# Person 920 = Introvert
# Person 921 = Extrovert
# Person 922 = Introvert
# Person 923 = Introvert
# Person 924 = Extrovert
# Person 925 = Introvert
# Person 926 = Introvert
# Person 927 = Introvert
# Person 928 = Extrovert
# Person 929 = Introvert
# Person 930 = Introvert
# Person 931 = Introvert
# Person 932 = Introvert
# Person 933 = Introvert
# Person 934 = Introvert
# Person 935 = Introvert
# Person 936 = Introvert
# Person 937 = Introvert
# Person 938 = Introvert
# Person 939 = Extrovert
# Person 940 = Introvert
# Person 941 = Extrovert
# Person 942 = Introvert
# Person 943 = Introvert
# Person 944 = Introvert
# Person 945 = Extrovert
# Person 946 = Introvert
# Person 947 = Introvert
# Person 948 = Introvert
# Person 949 = Introvert
# Person 950 = Introvert
# Person 951 = Introvert
# Person 952 = Extrovert
# Person 953 = Introvert
# Person 954 = Introvert
# Person 955 = Introvert
# Person 956 = Introvert
# Person 957 = Introvert
# Person 958 = Introvert
# Person 959 = Introvert
# Person 960 = Extrovert
# Person 961 = Introvert
# Person 962 = Introvert
# Person 963 = Extrovert
# Person 964 = Introvert
# Person 965 = Introvert
# Person 966 = Extrovert
# Person 967 = Introvert
# Person 968 = Introvert
# Person 969 = Introvert
# Person 970 = Introvert
# Person 971 = Introvert
# Person 972 = Introvert
# Person 973 = Extrovert
# Person 974 = Introvert
# Person 975 = Introvert
# Person 976 = Introvert
# Person 977 = Introvert
# Person 978 = Introvert
# Person 979 = Introvert
# Person 980 = Extrovert
# Person 981 = Introvert
# Person 982 = Introvert
# Person 983 = Extrovert
# Person 984 = Introvert
# Person 985 = Introvert
# Person 986 = Introvert
# Person 987 = Introvert
# Person 988 = Introvert
# Person 989 = Introvert
# Person 990 = Introvert
# Person 991 = Introvert
# Person 992 = Introvert
# Person 993 = Extrovert
# Person 994 = Introvert
# Person 995 = Introvert
# Person 996 = Extrovert
# Person 997 = Introvert
# Person 998 = Introvert
# Person 999 = Introvert
# Person 1000 = Introvert
