# %%
import urllib.request
import bs4
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import seaborn as sns
from sklearn.feature_selection import chi2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
DF = pd.read_csv('facebookdata.csv')

# %%
dataframe = DF.iloc[:,1:2]
DF_list = dataframe.values.flatten()

comment_list = list(DF_list)
comment_list
# Out:
# ['Ben Simmons will likely be the No. 1 pick of the NBA Draft, but who should it be?',
#  'How to coach the "Triangle Offense," as explained by Metta World Peace. (via QBronald/Twitter)',
#  'The new team, reportedly called the Black Knights, will be starting in 2017-18.',
#  'Derrick Rose has been traded to New York. The Knicks have a Big 3. STORY: http://ble.ac/28Nd0lA',
#  'The 38-year-old SG will test free agency.',
#  '2016 election motto: "No shirt, no problem" (via florentips/Twitter)',
#  "The NBA Finals are behind us and the draft is tomorrow, so it's time to talk hoops on The Simms & Lefkoe Podcast. Ric Bucher and Howard Beck join Simms and Lefkoe to talk LeBron's legacy, Warriors, Cavs, Draft and plenty more.",
#  'Earl Joseph Smith III. Legend. (via NBA TV)',
#  'King James on his throne 👑💯👑 #CavsParade (via NBA)',
#  '"If it was them in my shoes, would they turn down their dreams to play another year in college?"',
#  "Tristan Thompson is living it up at the Cavaliers' victory parade (via UNINTERRUPTED).",
#  'The #BR99 pop-up is officially live in NY! Come through. KITH Kith NYC.',
#  'Champagne showers provided by J.R. Smith. (via LindseyBaseball/Twitter)',
#  'Will a deal get done?',
#  "LeBron isn't going anywhere",
#  "J.R. Smith still hasn't found his shirt... #CavsParade (via mcten/Twitter)",
#  '#TrustTheProcess',
#  "Shaq is always ready! Don't try to be sneaky... (via Shaquille O' Neal)",
#  'The 30-year-old center will be heavily targeted.',
#  'Interesting spelling... 🤔',
#  'What other way to celebrate a title?',
#  'USA falls in the Copa America semi-finals to Argentina Recap: http://ble.ac/28PBSg9',
#  'Lionel Messi cements his name in the Argentina history books. (via Bleacher Report UK)',
#  'What a goal.',
#  'The high demand forced them to cut the original time slot.',
#  '"(Adam) Morrison picked me up in a black Maserati. He was wearing fitted black jeans... No more mustache, hair thin and tied up in a tight ponytail. He looked...completely normal." http://ble.ac/28Mb6Uj',
#  'His salary next season would have been over $23 million.',
#  'We took an in-depth look into how Leo Messi changed football forever.',
#  '13 years later, LeBron fulfills his promise to his younger self.',
#  'Does anyone in this year\'s draft class have a chance at getting a role in "Space Jam 2"?',
#  'His opponent had no words... (via International Table Tennis Federation)',
#  'Could be a huge week for the 76ers...',
#  'So does Adam Morrison have an apocalypse bunker or not?',
#  "It's happening.",
#  'Let the rumors begin...',
#  '"You play basketball? I hate that sport, man." 😂',
#  'Same story, new chapter for the Warriors',
#  'You witnessed the NBA playoffs but not quite like this. Relive the greatest moments, emoji-style.',
#  'The star-studded lineup includes Dwyane Wade, Von Miller and Vince Wilfork.',
#  "It's been a long road for D-Wade, but he ain't done yet.",
#  'Get you a man who can do both',
#  'Russell really went there. 😂😂😂',
#  'Is that Odell Beckham Jr. or Happy Gilmore? (via SeanTMcMann/Twitter)',
#  "Should've bet on LeBron.",
#  "Haters will say it isn't a skill... (via IG/jay_2524)",
#  'Happy days in Cleveland.',
#  'Priceless.',
#  'Starbury!',
#  "LeBron's critics have nothing left.",
#  'LeBron is 1st player to lead all players in all stat categories in an entire playoff series',
#  'LeBron James is back on social media...with a new friend',
#  'With his 3rd Finals MVP, LeBron joins an elite club. #MakeHistory',
#  "We're getting down with NYC's finest KITH to bring you the first ever #BR99 pop-up experience. We're setting up shop in Manhattan June 22 - June 30, 12-8pm. Collab gear, @Kithtreats, a BR99 custom video lab, nightly speakers series and plenty of vibes. 79 Greene St. in SoHo.  Come through. 🔥",
#  'LeBron brings the 🔥.',
#  '"He was timid and shy and scared and afraid."',
#  "Coach K and John Calipari aren't messing around.",
#  'From wine and gold to purple and gold?',
#  'LeBron James: #KingOfTheLand',
#  "Want more of this? Download Team Stream and subscribe to the NBA stream for full coverage of the Cavs' celebration: http://ble.ac/28JArPe",
#  "Someone with the Heat wasn't too happy with his decision to leave...",
#  "The King wasn't letting anyone take his trophy.",
#  'Ezekiel Elliott and his fellow rookies look ready for the end zone.',
#  'The playoffs proved to be a different beast for the Warriors',
#  '"This is why you can\'t mess around. Not that we messed around, but this is why every game counts." - Steve Kerr',
#  '"I can\'t get traded now…right?"',
#  'When you watch your 73-win and unanimous MVP season go up in smoke...',
#  "When it's Game 7, never shy away from a shot. Even if you're a fan.",
#  'Goosebumps.',
#  'Savage. 😂',
#  'The moment when 52 years of suffering ends... (via Cleveland Cavaliers)',
#  'Earned. 🖐',
#  "Guess what time it is? Savage o'clock #Dab",
#  'The Cavs were flying over Vegas last night, so they decided to make a quick pit stop (via ArashMarkazi/Twitter).',
#  'Kentucky Wildcats star Jamal Murray joins Adam Lefkoe to discuss his trademark celebration and take aim with a real bow and arrow as he prepares to be selected in the lottery of the 2016 NBA Draft.',
#  "When it's Monday in Cleveland and no one is goin' to work",
#  'The dagger for the trophy.',
#  'Kyrie had the Mamba Mentality tonight.',
#  'The Cavs can now pop bottles.',
#  'Cleveland is going crazy tonight. (via itsramalamadingdong, __chocolatekisses__ & uberharold/Instagram)',
#  'J.R. Smith with an emotional postgame presser. (via KennyDucey/Twitter)',
#  'Kevin Love brings out his inner Stone Cold Steve Austin! (via Ananth_Pandian/Twitter)',
#  'Witnessed.',
#  'Respect.',
#  'Kyrie. LeBron. Pure emotion.',
#  'The end. #ViewsFromTheFinals',
#  'That championship moment. #ForTheLand',
#  'The Cavaliers are now kings.',
#  'JR Smith is an NBA Champion. #PipeGod',
#  nan,
#  'Cleveland finally ends their title drought! #MakeHistory',
#  'LeBron James leaves Oracle with a title and the rim.',
#  'LeBron James is the unanimous 2016 NBA Finals MVP.',
#  'What a series. Take a bow, LeBron James.',
#  'Champion.',
#  'LeBron carries Cleveland to an NBA Title. #Believeland',
#  'Congrats to Dustin Johnson for winning the U.S. Open. His first career major.',
#  'LeBron James is coming to take on the champ.',
#  'Spieth and other golfers chimed in.',
#  '1. More. Game.',
#  'On the first try. Steph is ready. (Via NBA)',
#  'Steph be like... (via chargercharlie/Instagram)',
#  'Whoops... 😱',
#  'Which Steph will show up in Game 7? #IMissCurry',
#  'Steph Curry. LeBron James. Game 7. #ClimbOn',
#  'Splash! Under the legs not once, but twice (via flight.nwh/Instagram)',
#  'It all comes down to this. #Game7',
#  'Is this the worst flop of all time? (via Bleacher Report UK)',
#  "Play us a song, you're the harmonica man!",
#  'Vandenburg faces 15 to 25 years in prison.',
#  'Ayesha Curry has garnered attention from her tweets recently.',
#  'The teams all paid tribute in different ways.',
#  "Now that's trust (via duck_dunn/Twitter)",
#  'Statement or just a happenstance of wardrobe?',
#  '"The Lakers are losing Kobe and they need a scorer. So why not call on me to fill in their spot?"',
#  "It's only right.",
#  'Reporter: "Will this game be the one to define your legacy?" LeBron James: "No."',
#  'What a guy.',
#  '"Doesn\'t mean a 50-point game, though."',
#  'Diet starts Monday.',
#  'Steph got jokes.',
#  "There's no place like home.",
#  'Dustin Johnson (-4) is just one stroke from tying the lowest score for a U.S. open winner at Oakmont #ClimbOn',
#  'Respect your elders, Ben.',
#  'The cap is expected to leap by $24 million.',
#  'Dorenbos explained a friend introduced him to magic after his father was convicted of killing his mother.',
#  'Started his Friday a bit early.',
#  'The fan was Andrew Forbes, son of Cavs minority owner Nate Forbes.',
#  'Government warned that "extreme economic measures would need to be implemented to successfully host the Olympic Games in August."',
#  'Game 7 tickets are selling for an average of $2,153 on StubHub.',
#  'D-Rose playing at MSG in 2016-17?',
#  'Kyrie Irving: Game 7 Ready! #NBAFinals',
#  'New York Knicks have had internal discussions about trading for Bulls guard Derrick Rose. STORY: http://ble.ac/1OuKJnC',
#  "It's getting heated...",
#  'Brotherly love from the Ryan bros.',
#  'Voice of reason, Metta World Peace (NSFW) #NotRigged (via Metta World Peace/Twitter)',
#  'LeBron taking dominant to a new level this #NBAFinals',
#  '"I\'m happy he threw his mouthpiece."',
#  'Curry caught all 6 fouls last night #GottaCatchEmAll',
#  'Hope meets hope.',
#  'Backs against the wall, LeBron James and the Cavaliers are ready to put the city on their backs.',
#  "Haters gonna say it's fake",
#  'Was a rough night for the Curry family.',
#  'LeBron James was out here dropping dimes!',
#  'LeBron James to Stephen Curry: "Sit down."',
#  'LeBron James was a different animal in Game 6.',
#  'Take a bow, LeBron James.',
#  'Started 3-1, now we here ... #ViewsFromTheFinals',
#  'LeBron James dancing into Game 7 like...',
#  'True.',
#  "The Cleveland Cavaliers ain't goin' nowhere!",
#  'The Cleveland Cavaliers are in good shape.',
#  'Just adorable.',
#  'Draymond Green is back. #ForgotAboutDray',
#  'Cleveland needs its superheroes to answer the call tonight.',
#  'The Cavs took down Oracle in Game 5, but a Warrior makes his return.',
#  'Ken Griffey Jr. reveals the special bond he had with Ichiro Suzuki.',
#  'Looks like the 63-year-old is a fan of video games.',
#  'Who did the potential No. 1 overall pick, Ben Simmons, choose to win the NBA title?',
#  'Well yeah.',
#  '"My first plan was to get back to my country, because I was...lost."',
#  'Tell us how you really feel, Von.',
#  'The mouthguard is expected to be auctioned off for up to $5,000.',
#  'Mets announce David Wright will undergo surgery to repair herniated disc in his neck; his return is TBD. STORY: http://ble.ac/1Pwi6RJ',
#  'Welcome to the NFL, rook!',
#  '"Freezing sperm is one of the measures I have to consider." 🤔',
#  '"Freezing sperm is one of the measures I have to consider." 🤔',
#  'Rough day for the rook.',
#  'Condolences, thoughts, and prayers to the families of the victims.',
#  'Amazing.',
#  'Who ya got?',
#  'Black uniforms worked in Game 5, can the blackout work in Game 6?',
#  'Ichiro led the American League in hits seven times and is a two-time AL batting champion.',
#  'His basketball game is just a bit more advanced than his football skills.',
#  'Poor Kevin Love.',
#  "Numbers don't lie ✔️✔️ #NBAFinals",
#  'Who ya got?',
#  'Game 5: "Bad Teammate" Game 6: Redemption?',
#  '"I have strong belief that if I play Game 5, we win Game 5"',
#  '🔥 or nah?',
#  'Respect for Black Mamba.',
#  'Colorado has also designated the SS for assignment.',
#  'Michael Irvin II was "brainwashed" at a young age by his father to attend the University of Miami. "I\'m meant to be there."',
#  'BREAKING: Andrew Bogut is reportedly out for the rest of the NBA Finals due to a knee injury.  STORY: http://ble.ac/23ah0D0',
#  'Just a day away from the U.S. Open, Bubba is testing out a "new" chip shot... (via Bubba Watson)',
#  "This will be Sager's first NBA Finals game. #SagerStrong",
#  "The GOAT didn't approve... 😡",
#  'Motivation is the key to more success  (via Prairiedogpack)',
#  'Messi casually hits the goalie with a "nutmeg" (h/t Bleacher Report UK)',
#  'All those turnovers and defensive miscues added up.',
#  'But the star of the show was punter Pat McAfee',
#  'Whatever it takes to stay motivated.',
#  'This is just ridiculous. (via Central Coast Disc Golf/YouTube)',
#  'Their children answered questions like, "Where does your dad work?" ("in his office").',
#  'Yeezy Season.',
#  'USA summer goals.',
#  'Kyrie > Steph #NBAFinals',
#  'First world problems.',
#  "Don't bat-flip on Boston College.",
#  'Las Vegas could reportedly have a team as early as the 2017-18 season.',
#  'Bulls rebuild on the horizon?',
#  'Imagine a Thibs-Butler reunion in Minnesota... 👀',
#  'Chicago reportedly wants a top draft pick and an impact player in return for Butler.',
#  '21 years ago, the Rockets went back-to-back, became lowest-seeded team (No. 6) ever to win a title',
#  'Chicharito is a BIG fan of Watt.',
#  'High praise from The King',
#  "Game 6. June 14, 1998. Michael Jordan—in his final game in a Bulls uniform—caps off a second three-peat for Chicago with a clutch jumper over Utah's Bryon Russell. 🏆🏆🏆🏆🏆🏆",
#  'Julio Jones has the first hot dog covered.',
#  "What's wrong, Kyrie???",
#  "Kyrie Irving also put on a show last night to keep the Cleveland Cavaliers' season alive #NBAFinals",
#  "LeBron James was not ready for the Cleveland Cavaliers' season to end as he finished with 41 points, 16 rebounds, and 7 assists to force Game 6 #NBAFinals",
#  'Kyrie Irving froze the Warriors in Game 5.',
#  'Kyrie Irving joined Wilt Chamberlain in the history books tonight.',
#  'Shaun Livingston destroyed Richard Jefferson!',
#  'LeBron James with no mercy on the MVP!',
#  "LeBron wasn't the one crying at the end of Game 5... #LifeComesAtYouFast",
#  '"I\'m still part of the Big 3, right?"  "Dude, you scored 2 points in Game 5"',
#  'Kyrie and LeBron made more FGs than the whole Warriors team combined',
#  'Drake headed back to Cleveland. #ViewsFromTheFinals',
#  'What the Warriors saw tonight',
#  "The Cavs aren't done yet! #BreakingBron",
#  "Draymond Green got a hero's treatment across the way from Oracle at the A's game. (via DeMarcusRFNET/ Twitter)",
#  'Kevin Love had 2 points in the first half, did Cavs forget him in Cleveland?',
#  "Klay Thompson's three-point shooting this postseason has been crazy #ClimbOn",
#  'Uribe was hit by a 106 MPH grounder in the groin on Sunday.',
#  'The $63 million guaranteed is the most ever for a non-quarterback.',
#  'With a win tonight, Steve Kerr will join an elite club. #ClimbOn',
#  'Win or go home for the Cleveland Cavaliers.',
#  '"If you have a girl bring her so she can see you get embarrassed"',
#  'From wayyy downtown! #Buckets (via bryanharsin/Twitter)',
#  'Robinson could join the Legion of Boom in the secondary...',
#  'Not "with the physicality and the words guys said to each other back then"',
#  '3 defenders vs. 1 dunker= No big deal (via therealfrequentflyer/Instagram)',
#  'Just 1 win away from history for the Golden State Warriors.',
#  "A change at the helm didn't hurt the Penguins from their Stanley Cup chase. #ClimbOn",
#  "If Green can't wait watch the game at Oracle Arena, then why not next door.",
#  '"To the city of champs."',
#  'The push to have the regents vote is being driven by some of the big-money donors.',
#  "Cristiano Ronaldo and Zlatan Ibrahimovic are beasts of Europe, but which titan will become the Euros' all-time leading scorer?",
#  'Still got it.',
#  'Champions. #StanleyCup',
#  'Congratulations to the Pittsburgh Penguins! 2016 Stanley Cup Champions! RECAP: http://ble.ac/1UplfZd',
#  'Anything is possible! (via IG/alexpoling1)',
#  'His suspension prohibits him from being at the arena during Game 5.',
#  'Whatever it takes to get him to stay.',
#  'This is absolutely unreal! (via Red Bull)',
#  'Chuck goes in detail about the LeBron-Draymond incident in this B/R Exclusive.',
#  'Legend.',
#  "LeBron James couldn't hide his reaction once he heard of Klay Thompson's comments.. #NBAFinals",
#  'Draymond right now after being suspended for Game 5.',
#  'The Cavs coach believed the Warriors repeatedly got away with fouling LeBron James.',
#  '"The Draymond news has me like.."',
#  'BREAKING: Draymond Green receives a Flagrant 1 for his actions in Game 4 incident with LeBron James, will be suspended for Game 5. James assessed a technical foul.STORY: http://ble.ac/1tqfUHm',
#  'GRONK SPIKE. 💪💪',
#  'Magic\'s "opinions, comments and social media posts are solely his and do not represent or reflect those of Lakers ownership or management."',
#  'There is "no known timetable yet for a ruling."',
#  'No love for being one win away from another championship, huh?',
#  'Good guy Big Papi.',
#  'Clint Dempsey scored the only goal to lead USA.',
#  'Even the G.O.A.T. was a troll back in the day.',
#  'By a nose!',
#  '"Other than LeBron, I don\'t really know who else to vote for."',
#  'Luckily, the MVP has a sense of humor.',
#  'The young Griffey is a football player at Arizona who quit playing baseball in 2006.',
#  '"That\'s my job, to go out there and play and help us win games."',
#  '"[Joe Lacob] and the Warriors owners have said all along that he will pay to keep a winning team together."',
#  '"O.J. wanted to hear the end of the game on the radio before he pulled in."',
#  "Because it's what Lionel Messi does.",
#  'Draymond vs. LeBron',
#  "YouTube star Vitaly Zdorovetskiy didn't make it very far on the court",
#  'Cleveland Cavaliers may have lost but Kyrie Irving cooked Chef Curry!',
#  'True or false?',
#  'Not a good sign for the Cleveland Cavaliers.',
#  'Draymond is the only Warrior to play in all 88 wins this season',
#  'Another game, another record for the Warriors',
#  'Frenemies unite! #ViewsFromTheFinals',
#  'The Warriors played BIG tonight!',
#  'Warriors escape Cleveland with a 3-1 lead',
#  "Andrew Bynum is chillin'.",
#  'Rockets guard James Harden withdraws from the 2016 Olympics. Details: http://ble.ac/1RZDQVS',
#  "Well, that's different.",
#  'Legend.',
#  'Russell Westbrook has withdrawn from the 2016 Olympics. Details: http://ble.ac/22ZkyI3',
#  'Boogie has been "told he has earned a roster spot."',
#  'These bottle flips seem legit (via dschwartin7/Twitter)',
#  'Will the Cavs continue their dominance at home? #ClimbOn',
#  'Texas A&M QB commit Connor Blumwick goes  yards with a vortex  (via @BR_TheFuture/ Twitter)',
#  'Sources close to the situation described the incident as "a setup."',
#  'Among other things she said she "didn\'t even know Mexicans were that smart."',
#  'These contract negotiations are getting tense...',
#  '"Love you brother we all good and I can see you are a true one."',
#  '#RIP to the GOAT.',
#  'The evolution of the water bottle flip (via nixon.19, clay_barnett25, uber38/IG).',
#  '"We\'ll deal with that at a different time."',
#  "Don't count out the Cavs yet!",
#  'Red Wings legend Gordie Howe, known as Mr. Hockey, has passed away at the age of 88 #RIP DETAILS: ble.ac/21coOCv',
#  'PSA: Remove cell phone from hand before attempting to catch a home run.',
#  'Hard work will be rewarded  (via yrn.drake/Instagram)',
#  'San Jose Sharks win on the road to force a Game 6 with the Pittsburgh Penguins. Recap: http://ble.ac/1Xdh04R',
#  'Never change, JR Smith.',
#  'The Warriors center defends the injured big man.',
#  'Moniak becomes the first outfielder selected No. 1 overall since Bryce Harper in 2010.',
#  'Draymond says the Cavs were hungrier in Game 3.',
#  'LeBron James put up another 30-10-5 game in the Finals last night. #ClimbOn',
#  'The Dab goes into "The Hall"',
#  "If you like your job, then don't do dumb things like this.",
#  "BREAKING: Orioles' Manny Machado has reportedly been suspended four games and received a $2,500 fine for brawl vs. Royals. Royals' pitcher Yordano Ventura has been suspended nine games. STORY: http://ble.ac/1XJ3g2J",
#  'With Euro 2016 starting tomorrow, relive some of the iconic goals and past magic (via @br_uk)  http://ble.ac/1UGcg4y',
#  'Hillary Clinton to Donald J. Trump.',
#  "Superfan Jimmy Goldstein dropped $500K on NBA tickets this year. That gets you over 1,400 pairs of Yeezy's!!",
#  '"I really don\'t like to go out and say I\'m the No. 1 prospect, I just let \'em all find out for themselves."',
#  'No love for the Carolina Panthers supporter...',
#  'Kevin Love has really struggled against the Warriors.',
#  'Can you name the 5 pitchers drafted ahead of him?',
#  'Who is "they"? And why did Teague delete the post? 🤔',
#  'BREAKING: Rafael Nadal announces he will miss Wimbledon due to wrist injury. STORY: http://ble.ac/21atJUF',
#  '"The King wants his crown back? He never took it off."',
#  'Cam is working on "new stuff" for next season.',
#  "Draymond Green's trash-talking never stops...",
#  'With an offer from Alabama already, Jesus Machado Jr. is about to become big-time.',
#  'So close!',
#  "Last night's presser was the only place the Cavs struggled last night... (via Cavs, h/t talkhoops/Twitter)",
#  'LeBron James played like the King last night in a crucial Game 3 victory',
#  'LeBron James got wayyy up for that dunk!',
#  'LeBron James stuffs the MVP after the whistle',
#  'Warriors may have lost by 30 but Draymond Green still took time to pose with a fan.',
#  'Kyrie Irving brought his A-game tonight in Game 3. #UncleDrew',
#  "Safe to say LeBron James' words resonated with the Cleveland Cavaliers tonight.",
#  'Warriors suffer another blowout in the playoffs.',
#  "What's a team when its most important fan is missing? #ViewsFromTheFinals",
#  'Put some RESPEK on his name!',
#  'Sweep? LeBron James says NO!',
#  'LeBron James continues to #MakeHistory in the NBA playoffs',
#  'Rough 1st half for Stephen Curry.',
#  'Kyrie Irving was deadly accurate in the 1st quarter!',
#  'Wow.',
#  'What if?',
#  'Tyronn Lue keeps it real on the infamous stepover.',
#  'Imagine LeBron in the red zone.',
#  'That sick feeling when he re-read the cards...',
#  "Andre Iguodala isn't giving LeBron any room to operate.",
#  'The clothing, cars and travel bills add up...',
#  'Still not as bad as 50 Cent.',
#  'Kobe Bryant is all about making dreams come true #AllTheFeels (via vanessabryant/IG, h/t cali_coupons11/IG) STORY: http://ble.ac/25MC3k1',
#  "Not in Andre Drummond's house! #Denied (via sebastian.pfaffnba/Instagram)",
#  'Can the Cavs keep their home-court winning streak alive tonight?',
#  '1. Brawls with Yordano Ventura: ✅  2. Gets offered free food for life: ✅',
#  'LeBron and the Cavs are tired of being bullied',
#  'BREAKING: Maria Sharapova has been given a two-year suspension for an anti-doping rule violation.  STORY: http://ble.ac/1sw1WD8',
#  "Oh no he didn't! Not the RKO! (via zacyounghighlights/Instagram)",
#  'A relationship unlike any other.',
#  "Yordano Ventura hit Machado with a 99 MPH fastball and Machado didn't appreciate it.",
#  'Team USA recovered from their opening game loss to defeat Costa Rica, 4-0 in Copa America (photo via Bleacher Report UK) Recap: http://ble.ac/1svDp0J',
#  "Auburn's Tiffany Howard makes a spectacular play with the game on the line! (via NCAAsoftball/Twitter)",
#  "It's a bit cheaper to get a NBA Finals ticket in Cleveland than in the Bay Area.",
#  '15-1 vs. 73-9',
#  "Living up to his 'Money' moniker.",
#  'Condolences to his family. Rest in peace.',
#  "Showtime Lakers vs. 2016 Warriors. Who ya' got?",
#  'LeBron James is going all out for Game 3.',
#  'Yep, he did that. (via Matt Moreno/Vine)',
#  '"If you dare to score against my team-mates, I will find you and crush your head like I did the Red Viper."',
#  nan,
#  'He is still suffering from lingering injuries.',
#  'How did the Warriors go from boos to defending champions?',
#  "How good is 4-star Clemson commit Cordarrian Richardson at guessing what's on his pizza?",
#  '"That fight divided people. It divided families. It divided cultures." -Oscar De La Hoya',
#  "NFL's Twitter account was hacked today. Did someone take up a new hobby this offseason?",
#  "That's one way to open a bottle of champagne (via Josh Kelley Golf)",
#  'SPIN MOVE. 👀',
#  'Kimbo took his gift and marketed himself to the moon.',
#  'Shaq smiled and responded, "I don\'t remember."',
#  'Marrone credits his New York roots for his rapping skills.',
#  "The organization still maintains Helwani's actions were wrong.",
#  'MMA icon Kimbo Slice passes away at age 42. DETAILS: http://ble.ac/1Yc63Aj',
#  'Pittsburgh Penguins defeat the San Jose Sharks, 3-1 in Game 4 Take a 3-1 series lead  One more win #StanleyCup RECAP: http://ble.ac/1Yc4BOf',
#  '#PuigMyFriend',
#  'He originally wanted to jump over a convertible.',
#  'Service will be held on June 10th.',
#  '#MJMondays',
#  'Green Bay fans might not love this...',
#  'Not as bad as his golf swing at least...',
#  'Might need to check for cracks in those things...',
#  'Captain Omaha meets President Obama.',
#  'Manhandled...literally (via spindoctor_barbreakerz/Instagram)',
#  '"Where I\'m going, they don\'t celebrate 4th of July"',
#  "The MVP won't be going to Brazil due to his recent injuries.",
#  'The Warriors are an incredible +120 from downtown over their last four games. #ClimbOn',
#  'Livingston and Barbosa vs. Love and Irving: 21 buckets, 34 fewer shots',
#  'AI.  Tyronn Lue.  15 years ago today...#legendary',
#  'Meet "piñata slayer." 😂',
#  '"You\'ll be taken to a point where you want to break..."  Inside the #Elite11 in LA.',
#  '"I don\'t care what anyone says, there\'ll never be anyone like him again."',
#  'Now this is how you take your offseason workouts to the next level... (via Cajun_73/Twitter)',
#  'B/R EXCLUSIVE: Here are the 12 #Elite11 QBs going to #TheOpening this July!',
#  'Stephen Nelson and Michael Felder reveal the 2016 Elite 11 class, exclusively on Bleacher Report. Come inside the War Room as Felder, along with Trent Dilfer and the rest of the coaches, pick the top high school quarterbacks in the country',
#  'Don\'t mess with Shaq, Bogut!  "Welcome to D\'Angelo Russell Studios: The Australian Office" (via willsherratt/Twitter)',
#  "The former UFC champ hasn't fought in the Octagon in five years.",
#  'The evolution of basketball = More fire? (via jesse_vr11/Instagram)',
#  "Since Draymond's toughness was questioned vs. OKC, the Warriors haven't lost.",
#  "Klay's father, Mychal, is not gonna be happy with his son this morning... (via NBA on TNT)",
#  'How the Greatest paved the way for the world we live in today.',
#  'Chef Curry playing 2K on the sideline #NBAFinals',
#  "Draymond Green's three-point shooting had Steph in awe. #NBAFinals",
#  "Drake gettin' hyphy after Game 2. #ViewsFromTheFinals",
#  'Ouch.',
#  'The Warriors literally blew out the Cavaliers in Game 2.',
#  'That 2-0 feeling. #NBAFinals',
#  'The Warriors destroyed the Cavaliers with ball movement. #NBAFinals',
#  'Warriors & Chef Curry cooked the Cavs tonight!',
#  "Tyronn Lue's game plan for the rest of the series.",
#  "When you agree to watch Game of Thrones after Game 2 but couldn't wait.",
#  'LeBron James already has the odds in his favor.',
#  'Rest in Power, Ali.',
#  'Watch as Stephen Nelson and Michael Felder break down the Elite 11 Finals from Los Angeles',
#  'Talib reportedly suffered a leg wound that has been categorized as minor.',
#  'Congrats to Novak Djokovic for completing the career Grand Slam! (via Bleacher Report UK) STORY: http://ble.ac/1sYUeRM',
#  "Can't wait.",
#  'Michael Bisping knocks out Luke Rockhold to become new UFC middleweight champion at UFC 199. (via Bleacher Report UK) Recap: http://ble.ac/1WADZXN',
#  'Is Drake rooting for the Warriors in the NBA Finals?',
#  'San Jose Sharks get their first Stanley Cup Final win in franchise history with 3-2 overtime victory against Pittsburgh Penguins. Series is 2-1, Penguins. Recap: http://ble.ac/1UpW7wU',
#  'Opponent unknown.',
#  'They were originally scheduled for UFC 200.',
#  'Mayweather bet on Game 6 of the WCF and Game 1 of the NBA Finals.',
#  'Lesnar last fought in the Octagon at UFC 141.',
#  'Lynch is from Oakland and went to Cal.',
#  'What are the chances?',
#  '"How many times have they been the favorite? None. Zero."',
#  '"All of his organs failed but his HEART wouldn\'t stop beating."',
#  'LeBron shares his thoughts and admiration for Muhammad Ali (via NBA TV)',
#  '5-star QB Tate Martell makes this throw look routine. (via BR_TheFuture/ Twitter)',
#  '"Float like a butterfly, sting like a bee."',
#  'How are you spending your Saturday? The Elite 11 QBs are grinding in LA. (via BR_TheFuture/ Twitter)',
#  nan,
#  'Clemson QB Deshaun Watson sat in the dunk tank at the Elite 11, and it became a splash zone.',
#  'Williams will have to wait until Wimbledon to try to claim her 22nd career Grand Slam.',
#  'Seager is the first Dodgers rookie since 1959 to hit three HRs in a game.',
#  '"What the Jackie Robinson is going on?"',
#  'The Greatest. #RIPMuhammadAli',
#  'Rest in peace, Muhammad Ali Details: http://ble.ac/1Pb8sUy',
#  'Interesting...to say the least.',
#  'Team USA takes on Costa Rica in its next game.',
#  '"I\'m so happy I stuck with football!"',
#  'Stay strong, champ.',
#  nan,
#  'Each ticket at Oracle Arena costs an average of $1,300.',
#  'Justin Bieber kicks around with Neymar and can actually keep up a bit (via Justin Bieber/Instagram)',
#  'The Cavs kept the Splash Bros. in check last night, but still took the L. Is Cleveland in trouble?',
#  '5-Star Clemson QB Hunter Johnson throws doughnuts to 4-Star Texas QB Sam Ehlinger #NationalDonutDay',
#  "The Cavs haven't had an answer for Shaun Livingston all season!",
#  'B/R Commitment Week is around the corner. Could this be you?',
#  'A whole lot of keyboard anger going around.',
#  "Why was Phoenix picked to be the ruined city in #GameOfZones? Download the Team Stream app for the exclusive #GoZ directors' commentary cut and more: http://ble.ac/1Um7o1x",
#  'Kerr went with a new offensive strategy last night... and it worked',
#  'I texted my daughter and said, "You need to know Drake just did this to me."',
#  "If they don't win with him, it says far more about them than about him.",
#  'Ouch.',
#  'All Stephen Curry needed was a jab step against Tristan Thompson',
#  'The Golden State Warriors bench showed out in Game 1.',
#  'Draymond Green kicks off the NBA Finals in his own way',
#  'And the ref goes down!',
#  "Drake's got the Dubs .... for now. #ViewsFromtheFinals",
#  'Warriors hustle the Cavs in Game 1!',
#  'LeBron James continues to break records. #NBAFinals',
#  "The Raptors are out, so who's Drake got now? #ViewsFromTheFinals",
#  'The Rematch.',
#  '#TrustTheProcess',
#  'Cavs are healthy, and fresher, for their Finals rematch vs. Warriors.',
#  'Who said dinosaurs were extinct?! (via K Powell/YouTube).',
#  "Did 2K get this year's cover athlete right?",
#  'Welp 😳',
#  'Phenom. Star. Icon. Convict. Michael Vick. "Vick," a B/R documentary, debuts in July.',
#  '"I want to give it a shot"',
#  '"I can\'t deny that the thought of being governor, the thought of being president, is alluring."',
#  'The reported deal is worth three years, $18 million.',
#  "It's finally here. Cleveland Cavaliers vs. Golden State Warriors. The rematch. Tonight.",
#  "They're back.",
#  'Will the Warriors go back-to-back?',
#  "Kevin Durant's love for LA is real, but it just doesn't make sense right now.",
#  'Who ya gonna call? Black Mamba. 🐍👻',
#  '#SagerStrong',
#  'Pittsburgh Penguins defeat the San Jose Sharks, 2-1 in OT of Game 2 Take a 2-0 series lead. #StanleyCup RECAP: http://ble.ac/1TKOm5n',
#  'Just in time for the NBA Finals.',
#  "The Golden State Warriors wouldn't be in the NBA Finals without making some history on the way!",
#  'Paul George has been chosen as the cover athlete for NBA 2K17 (via NBA 2K) Details: http://ble.ac/1WxxJjl',
#  "Kevin Durant isn't looking to be courted in free agency like LeBron.",
#  'Keep the crown, Steph just wants rings',
#  '"Well this \'little league ball park\' has seen the postseason more than you guys ever have."',
#  'MVPs prove their value when it matters most #ClimbOn',
#  'Look ma, no hands!',
#  '"It\'s been embarrassing. I don\'t know how else to put it."',
#  "Athletes didn't look like this a decade ago, but thanks to science they do now.",
#  "Wasn't exactly tough for the riders to figure this one out 😂",
#  'Byrd did not appeal.',
#  'He\'s resigning as a "matter of conscience"',
#  '"Dell Curry Jr." seeks the advice of the wise Sir Jordan in his quest for back-to-back titles #GameOfZones.',
#  'The resort has hosted the event for the last 55 years.',
#  "Neymar Jr.'s foot skills are excellent, but his swing game?",
#  'A trio of squires receive wisdom, a kingdom is ravaged and a king prepares for an inevitable battle #GameOfZones.',
#  'Nothing is stopping you #NoDaysOff (via Team Ezra)',
#  'Welcome to the Bay Area, LeBron... (via KatieABC7/Twitter)',
#  '"A major job of ownership is to find the right people to run the basketball side." - Celtics CEO Wyc Grousbeck',
#  "Beat Chris Sale in a game of rock-paper-scissors, and it's your lucky day! (via Superstr4/Twitter)",
#  "With a similar look to last year's jerseys, these are just as dope.",
#  '"Is [he] a male model or a football player?" - NFL coach',
#  "Russell Westbrook's playoff heat will truly be missed #NeverForget",
#  '"It\'s something people have to be careful with and worry about."',
#  'Surfing meets skateboarding. (via zoltantorkos/Instagram)',
#  "What do they know that we don't?",
#  'The young man can rake.',
#  'Troll So Hard.',
#  'The ceremonial first pitch will be with a football too 😂',
#  'He reportedly has been booked into Placer County Jail in California.',
#  'If he waits until next summer, Kevin Durant can sign a max deal worth over $200M with the Oklahoma City Thunder.',
#  '#Priorities',
#  'KD has a big decision on his hands!',
#  'OKC fans have a message for Kevin Durant: "Don\'t leave us"',
#  'Why you never make a bold bet on the Internet.',
#  'Does Anderson Varejao get a ring no matter what?',
#  'Back to work after a 3-day weekend like (via tmsgolfer/Instagram)',
#  'Superstars + Drama = Big Ratings',
#  'The Pro Bowl had moved around in recent years, being played in both Miami (2009) and Glendale (2014).',
#  'Russell Westbrook will be a free agent in 2017.',
#  'Steve Kerr telling it how it is.',
#  'In the wake of getting knocked out in the Western Conference Finals, Kevin Durant does not know what his future holds.',
#  '"We Almost got Lebron 2 years ago"',
#  "The #NBAFinals rematch we've all been waiting for",
#  "This is why we can't have nice things.",
#  "Don't come at the Queen V.",
#  'Stephen Curry and the Warriors kept their season alive with a Game 7 win last night.',
#  'Steph Curry made Russell Westbrook eat his words this series.',
#  'Thursday. Warriors. Cavs.   #NBAFinals #TheRematch',
#  'Both Splash Bros. break the previous record for 3s in a series.',
#  "It's all over! Warriors complete the comeback and stun the Thunder!",
#  'MVP Behavior. Dagger.',
#  'Steph Curry to Russell Westbrook right now.',
#  'Warriors knock out the Thunder!',
#  'Accurate.',
#  "Steph's shot was literally out of this world!",
#  'Just two competitors having a friendly a conversation. #Game7',
#  'Shaun Livingston with the hammer!',
#  'The Thunder executed early in the first half. Westbrook to Roberson!',
#  'Steven Adams. Grown man move.',
#  'How do you stop this? #ChefCurry',
#  "The Lakers co-owner puts an end to any speculation that he'll return to the organization.",
#  'Recent history gives the Oklahoma City Thunder the edge.',
#  'The ultimate field goal. (via chainsawlenon/Instagram)',
#  'Thunder. Warriors. Game 7.',
#  '"I\'m very well, thanks to God."',
#  'Oklahoma State shows you can put in the work AND have fun. (via rudolph2mason/Instagram)',
#  'Yes, you read that right... 🤑',
#  'Porzingod.',
#  'Football drills at the store, though? 😂😂 (via Vine/Chiefsami)',
#  'Tomorrow.',
#  'It will be a legacy defining game for Durant.',
#  'Draft a player that can do both...(via Ben Simmons)',
#  "There's no questioning Curry's toughness.",
#  'No surprise.',
#  'Rossi became the first rookie since 2001 to win the Indy 500.',
#  "There's no offseason when football is life. (via BGShaneBuechele/Twitter)",
#  'Classy gesture.',
#  "Bosh wanted to try to play in the playoffs, but the Heat didn't want to risk his health.",
#  "Julian Edelman has his quarterback's back. (via DRLandryy/Instagram)",
#  'When a player hits 11 3s in a playoff game, you bow down.',
#  'Revenge is a dunk best served cold',
#  'Klay was ridiculous',
#  'Impossible is nothing, see you in Game 7.',
#  "It doesn't get any easier than this... Russ to Roberson!",
#  "Doesn't get any better than that!",
#  'When you know you just got shook...',
#  '"Trust me when the offseason starts I\'ll be texting KD almost every other day recruiting"',
#  "Cris 'Cyborg' Justino calls out Ronda Rousey using #RunningManChallenge (via criscyborg/Instagram)",
#  'Pelicans guard Bryce Dejean-Jones dies at age 23. Story: http://ble.ac/1XF5uOQ',
#  '"OK" perfomance by the team, but a stellar performance by the fans.',
#  'Carmelo Anthony prefers his Big Apple whole.',
#  'LeBron James. 6 straight NBA Finals. #TakeABow',
#  'JR Smith was getting tired of carrying the trophy',
#  "LeBron James has some kind words for 'The 6ix' in his postgame interview.",
#  'Closeout game on the road? LeBron James played no games, finishing with 33 points, 11 rebounds and six assists to head to the NBA Finals once again.',
#  "When it comes to Champions League greatness, there's Real Madrid C.F. and then there's everybody else.",
#  "This Kyrie Irving shot didn't count but it was still amazing.",
#  'LeBron James and Drake exchanged words during the game and hugs after the game.',
#  'Kyrie Irving to LeBron James was a thing of beauty.',
#  'Nobody could stop LeBron James from reaching a 6th straight NBA Finals!',
#  "Just hold on you're going home. #CryingDrake",
#  "That's incorrect, Raptors.",
#  'Tony Hawk still got it.',
#  'This wakeboarder gets quite the surprise at the bottom of the water... (via @reedhansen/Instagram).',
#  'The Andrew Bynum hair chronicles continue.',
#  'Yes, you read that right.',
#  'Pretty hard to fake this stuff...',
#  'No Laughing Matter: Russ should check the stats',
#  'Forget Space Jam 2, maybe the Cavs should be in Pitch Perfect 3 (via teman_shaylor/Snapchat)',
#  '#TrustTheProcess',
#  'With The Indianapolis 500 this weekend, where did the crazy milk chugging tradition come from?',
#  'Mamba dipping his toes in the world of soccer.',
#  '"We didn\'t pay attention to details as much as we should have."',
#  'Finch will guest-manage the Bridgeport Bluefish for the day in addition to throwing out the ceremonial first pitch.',
#  'Nadal does not plan have surgery in the near future.',
#  '"[W]e didn\'t get to this point in our season by me taking over every game."',
#  "Russell Westbrook can only laugh when it comes to Steph's defense.",
#  'Sapp asked the Ravens "How do I stop this?"',
#  'The spelling game is not meant for the faint of heart.',
#  "Steph wasn't letting the Dubs season end last night",
#  'This is the second time that Kardashian has filed for divorce from the former NBA champion.',
#  'Can you use it in a sentence?',
#  "Andrew Bogut and Draymond Green are hitting Levi's Stadium after their Game 5 win!",
#  'Stephen Curry made sure his team would live to fight another day! #MVP',
#  'The Pittsburgh Penguins are heading to the Stanley Cup Finals after a 2-1 Game 7 win over the Tampa Bay Lightning! Recap: http://ble.ac/1P2dVC8',
#  'Steven Adams with the HAMMER!',
#  'Warriors came out ready to play!',
#  'Anthony Davis is not headed to the bank today after missing out on $24M',
#  "BREAKING: Houston Rockets are finalizing a deal to hire Mike D'Antoni as their head coach, per The Vertical with Woj DETAILS: http://ble.ac/249ZyNY",
#  "If at first you don't succeed, dust yourself off and try again (via hallofmeat/Instagram)",
#  'Briles went 65-37 in 8 seasons at Baylor.',
#  'What a moment.',
#  "DeAndre Jordan's inclusion is sure to spark some debates.",
#  'Fizdale has been the top assistant to Erik Spoelstra in Miami.',
#  '#HeyTeddy',
#  'From a 73-win season to an underdog on the brink. Tonight is win or go home for the Warriors',
#  'BREAKING: Baylor has reportedly dismissed head coach Art Briles. Update: Bears will reportedly name Phil Bennett interim coach.  STORY: http://ble.ac/1sAPfGD',
#  "Kyle Lowry's reaction to the Game 5 stat sheet was priceless",
#  'Time, money and private records potentially becoming public were reasons for the decision.',
#  'Mets Pitchers Noah Syndergaard and Jacob deGrom Join Adam Lefkoe for Who Wore It Better: Hair Edition Live.',
#  'B/R\'s Howard Beck says "Phil Jackson and Noah have a rapport."',
#  'Make baseball fun again.',
#  'San Jose Sharks are heading to the Stanley Cup Final for the first time in franchise history after defeating the St. Louis Blues in Game 6. Recap: http://ble.ac/1U8YDYl',
#  'TOUCHDOWN!',
#  'The Cavs tame the Raptors in Game 5!',
#  'Scully said he "felt it was not his place to be in someone else\'s broadcast booth."',
#  '"I want $100 million, up front..."',
#  'Disposable income at its peak. #Respeck',
#  '491 feet.',
#  "The images don't compare to the actual video.",
#  '"PSG and Manchester City can forget it."',
#  "They're not mentioned in the same breath as LeBron, but they can still shock the King.",
#  'NBA on TNT needs to make this happen.',
#  'Victor Oladipo doing his best Stephen Curry and Russell Westbrook impressions. (via Orlando Magic)',
#  'Judge also declined to reduce $140 million in damages awarded to Hogan.',
#  'Draymond Green receives text from Kobe Bryant after the Warriors\' Game 4 loss: "If making history was easy, why bother?" (via UNINTERRUPTED).',
#  '"Curry is not injured. He just had a lousy night."',
#  "Casey hasn't looked back since making the Eastern Conference Finals.",
#  "That 'stache though...",
#  "Well that's awkward...",
#  '"You have a free pass to blast me...I was f--king awful."',
#  'While the rest of the NBA is stunned, there were signs this was possible.',
#  'This dunker goes under-the-legs, over three people and... does it with a blindfold on! #TheDunkKing (via NBA on TNT)',
#  'Bottle flip game = 100 (via Mike_Senatore & ScottieFinanger/Twitter)',
#  'The Thunder have given Steph absolutely no room to operate',
#  'Klay had a tough time at the press conference last night...',
#  'No eyes, two hands in the cookie jar! #TheDunkKing',
#  "'Elevator' Ernie Johnson and Charles Barkley held a three-point contest.  Who took the NBA on TNT crown?",
#  'Russell Westbrook dominated the champions tonight with a triple-double in Game 4!',
#  'Thunder going back to Cali with a 3-1 lead! (via Pure Hoop)',
#  'Steven Adams has a cannon for an arm!',
#  'The Warriors may be in some trouble.',
#  'OKC came out ready in Game 4!',
#  'Well deserved. #SagerStrong',
#  '#SagerStrong',
#  '"We\'ve gotta come out & play with more desperation." - Draymond Green on Golden State Warriors Game 4 mentality. (via UNINTERRUPTED)',
#  'Uh oh.',
#  'Steven Adams gets protection for Game 4',
#  '"I can definitely see something in the future."',
#  '"They\'re not going to suspend Draymond Green. He\'s one of the premier players in the league."',
#  '"It\'s a violent game that I personally don\'t think humans are supposed to play."',
#  'These kids are not playing around (via grandytwins_boxing/Instagram)',
#  '"But we\'re still amateurs...Gotta love non-profits #NCAA"',
#  'Nadal gave perhaps his most dominating French Open performance yet.',
#  'Never give up on your dreams...',
#  'Nyquist won the Kentucky Derby and finished third at the Preakness Stakes.',
#  'Stuff has over 37,000 followers on Instagram.',
#  '"This is the beginning of bringing awareness."',
#  'The largest apparel deal in the history of college sports.',
#  '"If he continues this way for much longer he will die."',
#  'She\'s "happier than a Kardashian in an NBA locker room."',
#  'DeMar DeRozan dropped 32 points for the second straight game, helping the Raptors even the Eastern Conference Finals.',
#  'The Sharks are one win away from a Stanley Cup berth.',
#  "LeBron couldn't handle The North",
#  'DeMar DeRozan delivered a star performance in The 6ix as well. #WeTheNorth',
#  'Kyle Lowry brought his A-game tonight in Game 4 #WeTheNorth',
#  'BISMACK BIYOMBO says NO!',
#  'Series tied. We the North.',
#  'The rapper has a lot of fun in his latest short, entitled "Mean Guys"',
#  'BREAKING: The NBA will not suspend Draymond Green for Game 4 against the Thunder, per The Vertical with Woj DETAILS: http://ble.ac/27QTMFI',
#  'Valar Morghulis.',
#  'What an amazing gesture.',
#  '"It\'s one of the most troubling and disturbing reports I\'ve seen" - NFLPA Executive Director DeMaurice Smith',
#  'The star Pitt RB tweeted: "God is AMAZING. Just got the call that my body is clean of cancer!!!"',
#  'No worries, LeBron has got your back.',
#  'Draymond Green fires back at Russell Westbrook, who said his kick was intentional.',
#  '"We deeply regret that a mistake on our part has called this into question, but accept full responsibility."',
#  'All the feels.',
#  'Unbelievable throw down! #TheDunkKing (via NBA on TNT)',
#  "Here's how they're flipping the Billy Goat Curse on its horns.",
#  'Stance is taking over professional sports.',
#  "Russell Westbrook doesn't hold back his thoughts on Draymond Green's kick...",
#  "Now we'll see how Cavs handle their first bit of adversity in these playoffs.",
#  'Take notes coaches, this is how you celebrate! (via uncmenslacrosse/Twitter)',
#  "This is how you take LeBron James' flop from Game 3 to the next level (via BdotAdot5/Twitter)",
#  '"The facts here are so drastic, and so apparent, that the court should rehear it." - Brady\'s lawyer Ted Olson',
#  'Draymond Green has a new finishing move',
#  '"He didn\'t even look at the rim." #TheDunkKing',
#  'OKC beat Golden State by 28 to take the 2-1 series lead',
#  'Dahntay Jones got a 1-game suspension for this...What will Draymond Get?',
#  'That euro-step, though. #Westbrook',
#  'Steven Adams felt this one....#ouch',
#  'Serge Ibaka puts Festus Ezeli on a poster!',
#  'Oh. My. Goodness. (via jujimufu/Instagram)',
#  'Ouch! Alabama commit Najee Harris leaves the defender in the dust',
#  '"Some people like to poison the well" on Bleacher Report Radio.',
#  'Heads-up baserunning helped the Gators steal a run.',
#  'The former second-round pick still has a chip on his shoulder.',
#  'How could you do this to a child?!? (via Shaqtin_A_Fool/Twitter)',
#  'A putt that would make Happy Gilmore proud. (via ANordqvist/Twitter)',
#  'Ponies are so last year.',
#  'Will Beast Mode play in the NFL next season?"I don\'t put anything past him."',
#  "T.Y. Hilton's son is a spitting image of his dad on the football field. (via TYHilton13/Twitter)",
#  'Classic J.R. 😂',
#  'Like Jay-Z says... (via NBA TV)',
#  'DeMar DeRozan (32 points) led the Raptors to their first-ever victory in the Eastern Conference Finals.',
#  '"So I have to say something so I ask ummmmm did you just not want ME to sit next to you ?"',
#  'Drake trolled Paul George last series.',
#  'LeBron takes an elbow from his teammate and goes down for a while.',
#  'Bismack Biyombo had 7 points, 26 rebounds, 4 blocks and this finger wag in the Toronto Raptors Game 3 win!',
#  'Raptors dance their way to a Game 3 win!',
#  'Raptors Win! Mood:',
#  'Series is tied 2-2.',
#  'Blatt was fired by the Cavs earlier this season.',
#  'What if?',
#  "Exaggerator ends Nyquist's bid for the Triple Crown! #Preakness Recap: http://ble.ac/1RgmROC",
#  "Jose Mourinho reportedly agrees to become Manchester United's next manager. FULL STORY: http://ble.ac/1XIcI50",
#  'Nailed it.',
#  'One of his projects include short film based on "Dear Basketball" poem.',
#  '"I read some dumb things on here from time to time but wow."',
#  'This wiener dog could star in the next Air Bud: Save the Raptors (via Crusoe the Celebrity Dachshund)',
#  'Mark Cuban came out on the court... I gave my assistant a signal to throw me this oversized baby rattle, so I could reach it toward him: "You\'re a baby."',
#  'Consistency is key.',
#  '"My era, you always think that\'s the greatest era. But I\'m not so sure anymore."',
#  'Series is now tied 2-2.',
#  'Stay tuned.',
#  'The meeting reportedly did not go well.',
#  'Bobblebelly?',
#  "It's now been 22 years since Scottie Pippen put Patrick Ewing on a poster in the NBA playoffs.",
#  'The stadium was literally rocking.   (via wscsm_/Twitter, h/t Bleacher Report UK)',
#  'He was 7-for-10 from three-point land.',
#  'Ping pong matches are no longer safe.',
#  'KD & D-Wade?',
#  '🙈 🙉 🙊',
#  'NFL rookies play Pictionary with Bleacher Report live from the NFLPA Rookie Premiere.',
#  'LeBron James and the Cavs gave Tyronn Lue a water bottle shower after he broke an NBA playoff record (via UNINTERRUPTED).',
#  'Who needs human football players?',
#  '"You can\'t stop this one."',
#  'The organization has moved on "and so should everyone else."',
#  'LeBron James messed around and got a triple-double to put the Cavs up 2-0 vs. the Raptors.',
#  "Floyd reportedly hasn't asked Dana White yet.",
#  'Bosh is committed to getting back.',
#  'Sharks goalie Martin Jones has 58 saves in consecutive shutouts.',
#  'King. James. Slam. #Kaboom',
#  'Cleveland Cavaliers had everything going their way tonight!',
#  'With that win, Tyronn Lue enters the history books.',
#  "Raptors can't touch the Cavaliers as they take a 2-0 series lead",
#  '"That looks familiar." — Tyronn Lue looking on, probably.',
#  "Congratulations to LeBron James on passing Shaquille O' Neal for 4th on the NBA's all-time postseason scoring list #MakeHistory",
#  'LeBron James was clearly ready for Game 2 (via NBA)',
#  'Hassan Whiteside really named his red velvet cake "church" (via youngwhiteside/Snapchat, h/t houseofhighlights/Instagram)',
#  '"I like Draymond Green\'s intensity ... but every time I didn\'t get a call I didn\'t cry all the time."',
#  '1st Team All-Human',
#  'Could this tantalizing NBA prospect be the next Porzingis?',
#  "He might be suspended, but he won't be hungry.",
#  "Second year in a row that the team's top draft pick (Dante Fowler) has been injured before the season.",
#  'BREAKING: The Orlando Magic have reached an agreement with Frank Vogel to be their next head coach, per Orlando Sentinel. FULL STORY: http://ble.ac/20bUVSj',
#  '"The worst imaginable obstacles had been thrown in his path, but he refused to give in."',
#  'The tech company provides storage and infrastructure solutions.',
#  'Big men dominating the 1st team.',
#  'Nobody is safe from trolling in the Cavaliers locker room.',
#  'A Buckeye always pays his debts.',
#  "The Zen Master knows what he's doing.",
#  'A scout says "Dragan (Bender) is more advanced than Porzingis was when he was 18."',
#  "It's the first time since 1999 U.S. Open that Federer won't be in a Grand Slam singles main draw.",
#  "One of the top students in the Class of 2016 announces his commitment in a video unlike any you've seen.",
#  'Unreal play. 😱',
#  "UPDATE: Mickelson won't be charged criminally, but is named in lawsuit by SEC.",
#  'Yes, you read that right 😳💪',
#  'Andre Iguodala needs no eyes!',
#  'Between the legs! #TheDunkKing',
#  'When you realize the MVP is wide open.',
#  'The Golden State Warriors erupt for a 118-91 victory over the Oklahoma City Thunder to tie the series 1-1',
#  'Pittsburgh Penguins take Game 3 and a 2-1 series lead over the Tampa Bay Lightning with a 4-2 win. Recap: http://ble.ac/1OM0KVT',
#  'Instead of watching his shot, Stephen Curry decided to stare at Serge Ibaka.',
#  'Stephen Curry made it rain in the 3rd quarter with 17 points',
#  'Stephen Curry went into the crowd chasing a loose ball and it seemed like nobody wanted to catch him.',
#  'Russell Westbrook sliding into Game 2.',
#  'The New York Knicks are reportedly hiring Jeff Hornacek to fill their head coaching vacancy. Details: http://ble.ac/1OLhAEr',
#  'Transfers just two months after getting the ink. 🤔',
#  '"We don\'t do sports"',
#  'The OTL report also finds evidence of situations where cases were shielded from public view by Waco police.',
#  '"New phone, who dis?" 😂',
#  'Light-footed on and off the field.',
#  "Joey Crawford on NBA career: 'Sometimes I would get rattled' http://ble.ac/1V9uYUj",
#  'LeBron James has over 100 more playoff wins than the Toronto Raptors franchise.',
#  'RG3 called the offense "unacceptable."',
#  'Stephen A. Smith so fed up.',
#  'What a catch.',
#  'Looks like the Lakers would then be set at No. 2 with Brandon Ingram.',
#  'The Cleveland Cavaliers have yet to lose in these playoffs.',
#  'We can only hope there was video of his reaction 😂',
#  'LeBron James has some serious power.',
#  'Not even the rim had mercy on the Toronto Raptors tonight.',
#  "That's unfair, Kyrie Irving.",
#  'LeBron torched Toronto en route to an ECF Game 1 win',
#  'Kyle Lowry and the Toronto Raptors had no answers for the Cleveland Cavaliers in a 115-84 loss in Game 1.',
#  'The series now heads to San Jose.',
#  "It's NBA Draft Lottery night, when the future of a franchise could be decided in an instant. Stephen Nelson is joined by Ric Bucher, Howard Beck and Jonathan Wasserman to react to the results of Tuesday night's draw, and discuss which teams will target which players in the 1st Round.",
#  'For the first time ever, the NBA draft lottery went in projected order.',
#  'Where will Ben Simmons end up?',
#  'Where will Brandon Ingram end up?',
#  'The NBA Draft is on June 23.',
#  'Lakers reacting to the No. 2 pick',
#  'The Sixers have finally landed the No. 1 pick',
#  'Imagine if the team with the worst record actually got the No. 1 pick...',
#  'Celtics have a 15.6% chance of landing the No. 1 overall pick.',
#  'No replacement has been announced.',
#  "Don't mess with Toronto's mayor!",
#  'Longest blindfolded hook shot? Oh boy.',
#  "History is not on the Sixers' side",
#  'The Rangers 2B is reportedly planning to appeal.',
#  'After sweeping the first two rounds, their wait is over as the Cavaliers host the Raptors tonight in Game 1 of the Eastern Conference Finals.',
#  "LeBron's bank account after signing $1B Nike deal.",
#  'Game recognize game.',
#  '"Somebody told me he\'s the largest football player to ever play."',
#  "Who's going No. 1? And where?",
#  "That's how you troll.",
#  "There's more to sports than winning at the Special Olympics (via joeypogoda/Twitter)",
#  'All the feels.',
#  '"It was just a poor choice of words, mate."',
#  'The ultimate wait for it video... (via Jdill55/Twitter)',
#  'The film will release in 2017.',
#  'The Thunder stole Game 1 last night!',
#  '59" vertical confirmed  #TheDunkKing',
#  'Did the refs miss a 4th quarter travel?',
#  'Russell Westbrook dominated the second half of Game 1 #LetWestbrookBeWestbrook',
#  'Kevin Durant may have struggled tonight shooting the ball, but he came through when he was needed most.',
#  'Russell Westbrook 27 points, 12 assists, 7 steals, 6 rebounds Thunder defeat the Warriors, 108-102 Take a 1-0 series lead',
#  'Steph doing Steph things',
#  "Congrats to Stephen Curry on passing Steve Nash for 16th on the NBA's all-time postseason 3PM list #MakeHistory",
#  'If you hold a 3-point record Steph Curry will eventually break it',
#  '#MVPFlex',
#  '5/5 from the logo during warmups. Yup, the MVP is ready for the #WCF (via Twitter/erikmal)',
#  'Sick.',
#  "It's here.",
#  "Two decades of speculation came to an end when Fat Joe made an appearance on ESPN's Highly Questionable today.",
#  'Western Conference finals between the Warriors and Thunder starts tonight. You ready?',
#  'His injury could make him miss time during preseason.',
#  '"Russell was a great player, but he was a \'me\' player..."',
#  'Some serious hot takes.',
#  'This poster will look good in the locker room. (via keevo_9/Instagram, h/t House of Highlights)',
#  'Never give up.',
#  'The most affordable concession stands in professional sports.',
#  'Former Indiana assistant takes over after previous HC stints with Portland and Seattle.',
#  '"The other part of me was extremely annoyed." - Austin Collie on people\'s concerns over his concussions.',
#  "That's not quite where Tiger Woods was aiming for... (via barrysvrluga/Twitter)",
#  "Mayweather's barber says Money gets two, sometimes three haircuts per week.",
#  "Bosh's last two seasons have been cut short by blood clots.",
#  "Karl-Anthony Towns follows in Andrew Wiggins' footsteps, gives the Timberwolves #Back2Back Rookie of the Year awards.",
#  "Timberwolves' Karl-Anthony Towns goes from No. 1 overall pick to unanimous NBA Rookie of the Year!",
#  'They become the first major North American pro team to have sponsored jerseys.',
#  'Kyle Lowry on LeBron James: "One of the best players in the league besides Steph."',
#  'Puck played a game of hide-and-seek',
#  'Nothing beats a classic beard brawl.',
#  'Things got chippy today to say the least.',
#  'Nice gesture from KD.',
#  'Odor flips the script on Joey Bats!',
#  'DeMar DeRozan —> Kyle Lowry. The Raptors are heading to their 1st Eastern Conference Finals.',
#  'Whoa.',
#  'Kyle Lowry put the team on his back in Game 7!',
#  'Raptors KO the Heat in Game 7. LeBron and the Cavs got next',
#  '"I just kept talking junk to him and he kept staring at me."',
#  'A special father-son moment.',
#  '"The Olympics has been something I have admired since I was a little boy"',
#  'Jones\' record-setting jump would\'ve cleared Yao Ming (7\'6").',
#  'Views from the water.',
#  'The match was called off due to the discovery of a suspicious package.',
#  'Seven-time Cy Young winner vs. three-time NFL Defensive Player of the Year.',
#  'Rupp denied the Reds the tying run.',
#  'Just like old times.',
#  'The Cleveland Cavaliers and Cleveland Indians tweeted their congratulations.',
#  'She landed 29 of 42 strikes.',
#  "That's one way to avoid a tag  (via PatriotLeague/Twitter, h/t houseofhiglights/IG)",
#  'Campaign season.',
#  "That's an 8th grader. (via thekingkyree/ instagram)",
#  'Pacers are reportedly "finalizing a deal to promote assistant Nate McMillan to head coach" Details: http://ble.ac/1TeaUih',
#  'And a powder storm ensued.',
#  '15 up, 15 down.',
#  '"Happy birthday to my spirit animal" - Tom Brady',
#  'Steph Curry 99 Rating (2K) ALL. DAY. (via GQueFromJuice/Twitter)',
#  'Spieth ended up missing the cut.',
#  'All the feels.',
#  'Touching moment.',
#  '"It would have to be a boxing match."',
#  'And they did it on the road.',
#  'Terrence Ross terrorizing the rim!',
#  'Victor Oladipo made a special appearance and Dwyane Wade gave him the proper welcome.',
#  "Dwyane Wade wasn't ready for the season to end.",
#  'Josh Richardson went in full #Fridaythe13th mode for this dunk.',
#  'Wait for it...',
#  "Goin' back to Cali? Former Trojan DeMar DeRozan is reportedly interested in signing with the Lakers.",
#  'Forgive me father for I have sinned    (via @frank_stumpo, @mike.orso, @ben_barr_fanpage/Instagram)',
#  "He's 63 years old.",
#  "Miami vs. Toronto. Game 6. Who's doomed? #Fridaythe13th",
#  'Reyes will lose $7.06 million in game checks now that terms of the cumulative 52-game suspension.',
#  'Meanwhile… after an 8-0 start to the playoffs. (via Richard Jefferson/Snapchat, h/t Cavs Nation)',
#  '"I don\'t think it\'s his last one" - Draymond Green opens up on Stephen Curry\'s 2nd straight MVP (via UNINTERRUPTED).',
#  "Kwe Parker's legs could substitute as pogo sticks. (via Mars Reel)",
#  'Dothraki Steven Adams?',
#  '"So you put a onesie on a moose is what I got from that."',
#  'If this is the end, Tim Duncan goes out a playoff legend with his name all over the record books.',
#  'The percentage of a move "is now 50 percent—and maybe as high as 75."',
#  'Gregg Popovich is always handing out lessons and good insights at press conferences.',
#  'They will face the St. Louis Blues.',
#  'Tim Duncan discussed his future after the Spurs were eliminated. Story: http://ble.ac/24PjcAS',
#  'Pop keeps it real. Always.',
#  'Russell Westbrook is looking for revenge against the Warriors!',
#  ':(',
#  'Thunder knock out the Spurs. Next up: Warriors',
#  'The Thunder eliminate the Spurs! #Chance3',
#  '🙈',
#  '"It\'s kind of up to my kids, really."',
#  'Imagine if Cam Newton was on the Madden 17 cover.',
#  'Rob Gronkowski is your 2017 Madden cover athlete! Full story: http://ble.ac/1rIASQE',
#  "It's the Los Angeles Rams.",
#  'The elaborate scheme allegedly involved at least 15 medal-winning athletes.',
#  'Condolences and prayers to the family and friends of this young man.',
#  'Pick yourself up and try again. (via domogenesis/Instagram)',
#  'Biggest question marks at the NBA draft combine.',
#  '31 years ago today, the Knicks won the lottery that eventually landed them Patrick Ewing.',
#  'You stay classy, DC.',
#  'Jon Gruden says his love of football is "maniacal" and "sick."',
#  'Fourth-highest selling jersey will surprise some people.',
#  'Yes, you read that right...',
#  'The Black Mamba may have an apprentice.',
#  'Nobody is safe.',
#  "The fan's reaction is priceless.",
#  'Lockette suffered a season-ending neck injury last November.',
#  "Don't ever bet against Bartolo! 😂",
#  '"I am not the right head coach for this team".',
#  'Stephen Curry on what happens when bigs try to guard him: "BBQ chicken" (via NBAonTNT/Twitter).',
#  'Blazers were bounced by the Dubs, but not without earning their respect (via @Warriors/Twitter).',
#  'Klay Thompson helped close out the Blazers and send the Warriors to their 2nd straight WCF!',
#  'The MVP splashed home a dagger to seal the series.',
#  'Klay Thompson was a human torch tonight.',
#  'Season over. Warriors KO the Blazers.',
#  'Just the way they drew it up. #Warriors',
#  'Adam Silver left the MVP hanging #NoRespeck',
#  'Mad Max was in full effect tonight with 20 strikeouts.',
#  'DeMar DeRozan scores 34 points to lead the Toronto Raptors in a 99-91 Game 5 victory that puts them ahead 3-2 in the series',
#  'Bismack Biyombo put on a show in the 2nd quarter!',
#  'Max Scherzer ties MLB record by striking out 20 hitters in 9 innings against the Tigers. Details: http://ble.ac/24Ni2pu',
#  "The Thompson bros. have been killin' it for Cali.",
#  'School is officially in session (via solomon419_/Twitter)',
#  "He's not such a bad guy after all.",
#  "Bryce Harper suspended 1 game and fined for his actions after Nationals' walk-off win on Monday. He will appeal. Details: http://ble.ac/1TAkV5q",
#  '"[McGregor] is under contract with the UFC. Listen, if Floyd wants to fight Conor, call me, Floyd."',
#  "Can't be much more of a savage than this umpire... (via kipwilliams15/Twitter) STORY: http://ble.ac/1seskRT",
#  "We're gonna need 6 tombstones   (via norollsds/Twitter)",
#  "This pitcher's aim is unreal (via Pac12Network/Twitter)",
#  "It's the Floyd Mayweather/Conor McGregor fight you've been waiting for...on WWE 2K16 (via Shady00018)",
#  "How do you recreate Tiger Woods' famous chip shot at the 2005 Masters? With Legos of course (via goldyeller/Instagram)",
#  "The one-legged wrestler reached the highest of highs before falling into the abyss. Now he's rising again.",
#  'The previous record was 2,001 situps.',
#  'This is perfect. 😂',
#  'No one ever said Sanders was shy...',
#  '"The UFC is not for sale."',
#  'Steph Curry woke up like this... 🏆🏆',
#  '"For him to be that first player to get this unanimously, it just tells you how watered down our league is."',
#  "Dwight Howard stops by 'Inside the NBA' and doesn't hold back (via NBA on TNT) STORY: http://ble.ac/1TzXWY0",
#  'Russell Westbrook wanted to go back to OKC with a chance to end things, so he dropped 35 points.',
#  'Silva was supposed to fight Uriah Hall.',
#  'Russell Westbrook filled up the stat sheet tonight',
#  'Westbrook is relentless',
#  'Russell Westbrook seals the deal!',
#  'Kawhi Leonard throws it down, with AUTHORITY!',
#  'The old man can still get up! #TimDUNKan',
#  'When tied 2–2, Game 5 winners advance 81.9% of the time. Who you got?',
#  "Who won't be using the Warriors in 2K?",
#  "If Young Riley don't trust you",
#  'Riley Curry reminding the media who to vote for next year...or else. (via Twitter/abc7newsBayArea)',
#  'That\'s how you make the "Ultimate Chargers Mom" feel special.',
#  "One week from today, Ben Simmons' future becomes a lot clearer #NBADraftLottery",
#  "The jaw-dropping numbers speak for themselves. As does 'unanimous'. Congrats Stephen Curry.",
#  '31 years, 28 NBA draft picks, 8 national titles.',
#  'Heir to the Throne.',
#  'Spurs fans absolutely love Boban Marjanovic, the mysterious giant.',
#  nan,
#  "Steph Curry reminded us why he's the first unanimous MVP",
#  "Stephen Curry's regular season 3-pointers span longer than the Golden Gate Bridge.",
#  'Stephen Curry is the first unanimous MVP in NBA history.',
#  'Throwback Tuesday? 😂',
#  'Draymond Green says the Blazers-Warriors series is over.',
#  'Why use two arms when you only need one...',
#  "Don't ever mess with McLovin!",
#  'When you take a break from celebrating to curse out an ump.',
#  ...]

# %%
import re 
emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"              
         "]+", flags=re.UNICODE)
l = emoji_pattern.sub(r'',str(comment_list))

# %%
#z = l.split('\',')
res = l.strip('][').split('\',')

# %%
res[5]
# Out:
# ' \'2016 election motto: "No shirt, no problem" (via florentips/Twitter)'

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
test_subset=['MANISH OPEN UP ::,,,,,','ACHIN IS GOOD!!!!!']

sid = SentimentIntensityAnalyzer()
pos_word_list=[]
neu_word_list=[]
neg_word_list=[]

for word in res:
    if (sid.polarity_scores(word)['compound']) >= 0.5:
        pos_word_list.append(word)
    elif (sid.polarity_scores(word)['compound']) <= -0.5:
        neg_word_list.append(word)
    else:
        neu_word_list.append(word)                

#print('Positive :',pos_word_list)        
#print('Neutral :',neu_word_list)    
print('Negative :',neg_word_list[12])
# Out:
# Negative :  'The Cavs kept the Splash Bros. in check last night, but still took the L. Is Cleveland in trouble?
