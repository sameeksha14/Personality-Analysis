# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
dataset = pd.read_csv('facebookdata.csv')

# %%
dataset1 = dataset.iloc[:,1:2]

# %%
dataset1
# Out:
#                                          status_message
# 0     Ben Simmons will likely be the No. 1 pick of t...
# 1     How to coach the "Triangle Offense," as explai...
# 2     The new team, reportedly called the Black Knig...
# 3     Derrick Rose has been traded to New York. The ...
# 4             The 38-year-old SG will test free agency.
# 5     2016 election motto: "No shirt, no problem" (v...
# 6     The NBA Finals are behind us and the draft is ...
# 7           Earl Joseph Smith III. Legend. (via NBA TV)
# 8     King James on his throne 👑💯👑 #CavsParade (via ...
# 9     "If it was them in my shoes, would they turn d...
# 10    Tristan Thompson is living it up at the Cavali...
# 11    The #BR99 pop-up is officially live in NY! Com...
# 12    Champagne showers provided by J.R. Smith. (via...
# 13                                Will a deal get done?
# 14                          LeBron isn't going anywhere
# 15    J.R. Smith still hasn't found his shirt... #Ca...
# ...

# %%
CO_VCT = CountVectorizer()
comments_count = CO_VCT.fit_transform(dataset1)
TDIF_comment = TfidfTransformer()
TDIF_Comment_transform = TDIF_comment.fit_transform(comments_count)
